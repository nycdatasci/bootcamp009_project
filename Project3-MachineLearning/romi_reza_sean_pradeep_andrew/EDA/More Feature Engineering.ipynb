# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="ticks", palette="muted", color_codes=True)

# %%
# load dataset
df = pd.read_csv("./merged_w_state_build_year_2017-05-28.csv", parse_dates=['timestamp'], index_col=False, low_memory=False)

df.shape
# Out:
# (38123, 457)

# %%
df

# %%
plt.figure(figsize=(18,6), dpi=120)
# df['price_doc'].rolling(window=360,min_periods=10).median().dropna().plot()
# plt.plot(df['price_doc'], color='grey', alpha=0.3)

plt.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b9040c9b628b> in <module>()
#       2 # df['price_doc'].rolling(window=360,min_periods=10).median().dropna().plot()
#       3 # plt.plot(df['price_doc'], color='grey', alpha=0.3)
# ----> 4 sns.tsplot(time=df['timestamp'].values, unit=df['price_doc'].values)
#       5 plt.plot()
#
# TypeError: tsplot() takes at least 1 argument (2 given)

# %%
plt.figure(figsize=(18,6), dpi=120)
df.groupby(['year','month']).median()['price_doc'].plot()
