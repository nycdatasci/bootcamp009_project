# %%
import re

# %%
text = "{{tag1}} hello {{tag2}}"

# %%
re.split(pattern="{{|}}", string=text)[1::2]
# Out:
# ['tag1', 'tag2']

# %%
import pandas as pd

# %%
pov = pd.read_table('pov.txt', header=None)

# %%
pov.head()
# Out:
#                                                    0
# 0  Row(id=5597, title=u'Politics of Cyprus', _VAL...
# 1  Row(id=14668, title=u'Economy of Iraq', _VALUE...
# 2  Row(id=24400, title=u'Pair programming', _VALU...
# 3  Row(id=26131, title=u'Racial profiling', _VALU...
# 4  Row(id=32783, title=u'Antisemitism and the New...

# %%
list(pov.iloc[0])[0].split("_VALUE=u'")[1]
# Out:
# '{{multiple issues|\\n{{POV|date=November 2013}}\\n{{Refimprove|date=August 2007}}\\n}}\\n{{Politics of Cyprus}}\\n\\nThe [[Republic of Cyprus]] is a [[unitary state|unitary]] [[presidential system|presidential]] [[representative democracy|representative republic]], whereby the [[President of Cyprus]] is both [[head of state]] and [[head of government]]. [[Executive power]] is exercised by the government. [[Legislative power]] is vested in both the [[Forms of government|government]] and the [[House of Representatives of Cyprus|parliament]]. The [[Judiciary]] is independent of the executive and the legislature.\\n\\nCyprus has been a divided island since 1974 when Turkey invaded the north in response to a military coup on the island which was backed by the Athens government.<ref>{{cite web|title=Cyprus profile|url=http://www.bbc.com/news/world-europe-17217956|website=BBC News|publisher=BBC News|accessdate=2 February 2015}}</ref>  Since then, the internationally recognized Republic of 
# ...

# %%
re.sub('([\[\]\}])|(\\\\n)|(\\\\)|(\')|(</ref>)', '', 
       re.sub('(<ref>[ -Z\\\\^-z]*</ref>)|(<br>)|(={2,3}[ -Z\\\\^-z]*={2,3})', '', re.sub('\|[ -Z\\\\^-z]*\]\]', '', 
       re.sub('{{[^}]*}}', '', re.sub('\[\[Image[^\]]*\]\]', '', string=list(pov.iloc[0])[0].split("_VALUE=u'")[1])))))
# Out:
# 'The Republic of Cyprus is a unitary state presidential system representative democracy, whereby the President of Cyprus is both head of state and head of government. Executive power is exercised by the government. Legislative power is vested in both the Forms of government and the House of Representatives of Cyprus. The Judiciary is independent of the executive and the legislature.Cyprus has been a divided island since 1974 when Turkey invaded the north in response to a military coup on the island which was backed by the Athens government.  Since then, the internationally recognized Republic of Cyprus has controlled the south two-thirds, and the Turkish Republic of Northern Cyprus, only recognized by Turkey, the northern one-third. The Government of the Republic of Cyprus has continued as the sole internationally recognized authority on the island (as well as the United Kingdom being internationally recognized with respect to the Sovereign Base Areas), though in practice its power e
# ...

# %%
pov_tok = pd.read_table('pov_tokenized.txt', header=None)
pov_tok.head()
# Out:
#                                                    0
# 0  Row(id=5597, title=u'Politics of Cyprus', text...
# 1  Row(id=14668, title=u'Economy of Iraq', text_c...
# 2  Row(id=24400, title=u'Pair programming', text_...
# 3  Row(id=32783, title=u'Antisemitism and the New...
# 4  Row(id=38424, title=u'Bikram Yoga', text_clean...

# %%
re.split('tokenized=', re.split('text_clean=u', pov_tok.iloc[0].values[0])[1])[1]
# Out:
# "[u'the', u'republic', u'of', u'cyprus', u'is', u'a', u'unitary', u'state', u'presidential', u'system', u'representative', u'democracy', u'whereby', u'the', u'president', u'of', u'cyprus', u'is', u'both', u'head', u'of', u'state', u'and', u'head', u'of', u'government', u'executive', u'power', u'is', u'exercised', u'by', u'the', u'government', u'legislative', u'power', u'is', u'vested', u'in', u'both', u'the', u'forms', u'of', u'government', u'and', u'the', u'house', u'of', u'representatives', u'of', u'cyprus', u'the', u'judiciary', u'is', u'independent', u'of', u'the', u'executive', u'and', u'the', u'legislature', u'cyprus', u'has', u'been', u'a', u'divided', u'island', u'since', u'1974', u'when', u'turkey', u'invaded', u'the', u'north', u'in', u'response', u'to', u'a', u'military', u'coup', u'on', u'the', u'island', u'which', u'was', u'backed', u'by', u'the', u'athens', u'government', u'since', u'then', u'the', u'internationally', u'recognized', u'republic', u'of', u'cyprus', u'has'
# ...
