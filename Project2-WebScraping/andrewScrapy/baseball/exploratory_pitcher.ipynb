# %%
import numpy as np
import pandas as pd

# %%
pitchers = pd.read_table("pitchers_cleaned.tsv")

# %%
pitchers.shape
# Out:
# (1572, 31)

# %%
pitchers.describe()
# Out:
#         year          name position  team  wins losses losses.1   era games  \
# count   1623          1623     1623  1623  1623   1623     1623  1623  1623
# unique   138            72        6   153    53     35       35   440    77
# top     None  Hoyt Wilhelm  Pitcher   NYY     0     11       11  None    35
# freq      28            41     1473    98    93    137      137    75    80
#
#           cg   ...       bk    wp    bf era_plus   fip  whip    h9   hr9  \
# count   1623   ...     1623  1623  1623     1623  1623  1623  1623  1623
# unique    67   ...       12    41   888      195   366   677   109    28
# top        0   ...        0     2  None     None  None  None   8.2  None
# freq     239   ...     1011   190   271      305   300    53    52   202
#
#          bb9       k9
# count   1623     1623
# unique    89     1374
# top      1.9  #VALUE!
# freq      77      163
#
# [4 rows x 31 columns]

# %%
list(pitchers)
# Out:
# ['year',
#  'name',
#  'position',
#  'team',
#  'wins',
#  'losses',
#  'losses.1',
#  'era',
#  'games',
#  'cg',
#  'sho',
#  'saves',
#  'ip',
#  'h',
#  'r',
#  'er',
#  'hr',
#  'bb',
#  'ibb',
#  'k',
#  'hbp',
#  'bk',
#  'wp',
#  'bf',
#  'era_plus',
#  'fip',
#  'whip',
#  'h9',
#  'hr9',
#  'bb9',
#  'k9']

# %% [markdown]
# Covert "None" to NaN.

# %%
pitchers = pitchers.replace('None', np.nan)

# %%
pitchers.isnull()
# Out:
#        year   name position   team   wins losses losses.1    era  games  \
# 0     False  False    False  False  False  False    False  False  False
# 1     False  False    False  False  False  False    False  False  False
# 2     False  False    False  False  False  False    False  False  False
# 3     False  False    False  False  False  False    False  False  False
# 4     False  False    False  False  False  False    False  False  False
# 5     False  False    False  False  False  False    False  False  False
# 6     False  False    False  False  False  False    False  False  False
# 7     False  False    False  False  False  False    False  False  False
# 8     False  False    False  False  False  False    False  False  False
# 9     False  False    False  False  False  False    False  False  False
# 10    False  False    False  False  False  False    False  False  False
# 11    False  False    False  False  False  False    False  False  False
# ...

# %%
np.sum(pitchers.isnull())
# Out:
# year          0
# name          0
# position      0
# team          7
# wins          0
# losses        0
# losses.1      0
# era          25
# games        17
# cg            0
# sho           0
# saves         0
# ip            0
# h             0
# r             0
# er           24
# hr          150
# bb            2
# ibb           0
# k           112
# hbp         159
# bk          158
# wp          119
# bf          220
# era_plus    254
# fip         249
# whip          4
# h9            2
# hr9         151
# bb9           4
# k9            0
# dtype: int64

# %% [markdown]
# Okay. Where do we start. Let's just take a look at some of these rows. Rember, we don't want to get rid of too many, we only have 1600 rows.

# %%
pd.set_option('display.max_columns', None)
pitchers.loc[pitchers['ibb'].isnull(),:]
# Out:
#       year               name                 position     team wins losses  \
# 15     NaN       Bruce Sutter                  Pitcher      NaN  NaN    NaN
# 17    1900  Christy Mathewson                  Pitcher      NFK   18      2
# 18    1900  Christy Mathewson                  Pitcher      NYG    0      3
# 19    1901  Christy Mathewson                  Pitcher      NYG   20     17
# 20    1902  Christy Mathewson                  Pitcher      NYG   14     17
# 21    1903  Christy Mathewson                  Pitcher      NYG   30     13
# 22    1904  Christy Mathewson                  Pitcher      NYG   33     12
# 23    1905  Christy Mathewson                  Pitcher      NYG   31      9
# 24    1906  Christy Mathewson                  Pitcher      NYG   22     12
# 25    1907  Christy Mathewson                  Pitcher      NYG   24     12
# 26    1908  Christy Mathewson                  Pitcher      NYG   37     11
# ...

# %% [markdown]
# Replacing all missing IBB's with 0

# %%
pitchers['ibb'] = pitchers['ibb'].fillna(0)

# %% [markdown]
# Because there are a few relievers in the HOF, I'm going to fill any missing saves with 0, as well as any CG or SHO

# %%
pitchers.loc[pitchers['k'].isnull(),:]
# Out:
#       year            name                position     team wins losses  \
# 15     NaN    Bruce Sutter                 Pitcher      NaN  NaN    NaN
# 58    1928  Walter Johnson                 Pitcher      NWK    0      0
# 82    1910  Pete Alexander                 Pitcher      SYR   29     11
# 104   1930  Pete Alexander                 Pitcher      DAL    1      2
# 126   1877  Candy Cummings  Pitcher and Outfielder      LYN    1      7
# 143   1919        Ed Walsh                 Pitcher      MLW    2      2
# 144   1920        Ed Walsh                 Pitcher      BPT    1      1
# 145    NaN    Rube Waddell                 Pitcher      NaN  NaN    NaN
# 153   1902    Rube Waddell                 Pitcher      LOS   11      8
# 162   1910    Rube Waddell                 Pitcher      NWK    5      3
# 164   1911    Rube Waddell                 Pitcher      MNE   20     17
# 165   1912    Rube Waddell                 Pitcher      MNE   12      6
# ...

# %%
pitchers['cg'] = pitchers['cg'].fillna(0)
pitchers['sho'] = pitchers['sho'].fillna(0)
pitchers['saves'] = pitchers['saves'].fillna(0)

# %%
pitchers.loc[pitchers['r'].isnull(),:]
# Out:
#       year            name                  position team wins losses  \
# 15     NaN    Bruce Sutter                   Pitcher  NaN  NaN    NaN
# 145    NaN    Rube Waddell                   Pitcher  NaN  NaN    NaN
# 215    NaN  Clark Griffith    Pitcher and Outfielder  NaN  NaN    NaN
# 233    NaN  Clark Griffith    Pitcher and Outfielder  NaN  NaN    NaN
# 235    NaN  Clark Griffith    Pitcher and Outfielder  NaN  NaN    NaN
# 305    NaN    Herb Pennock                   Pitcher  NaN  NaN    NaN
# 336    NaN     Kid Nichols                   Pitcher  NaN  NaN    NaN
# 367    NaN      Dizzy Dean                   Pitcher  NaN  NaN    NaN
# 381    NaN      Dizzy Dean                   Pitcher  NaN  NaN    NaN
# 400    NaN    Chief Bender                   Pitcher  NaN  NaN    NaN
# 409   1913     Dazzy Vance                   Pitcher  SPI   11     14
# 415    NaN     Dazzy Vance                   Pitcher  NaN  NaN    NaN
# ...

# %% [markdown]
# Remove anything without "run"

# %%
pitchers = pitchers.dropna(subset=['r'])

# %%
pitchers.loc[pitchers['name'] == "John Smoltz",:]
# Out:
#       year         name position         team wins losses losses.1   era  \
# 1534  1987  John Smoltz  Pitcher  DET-ATL-min    4     11       11  5.73
# 1535  1988  John Smoltz  Pitcher      ATL-min   10      5        5  2.79
# 1536  1988  John Smoltz  Pitcher          ATL    2      7        7  5.48
# 1537  1989  John Smoltz  Pitcher          ATL   12     11       11  2.94
# 1538  1990  John Smoltz  Pitcher          ATL   14     11       11  3.85
# 1539  1991  John Smoltz  Pitcher          ATL   14     13       13   3.8
# 1540  1992  John Smoltz  Pitcher          ATL   15     12       12  2.85
# 1541  1993  John Smoltz  Pitcher          ATL   15     11       11  3.62
# 1542  1994  John Smoltz  Pitcher          ATL    6     10       10  4.14
# 1543  1995  John Smoltz  Pitcher          ATL   12      7        7  3.18
# 1544  1996  John Smoltz  Pitcher          ATL   24      8        8  2.94
# 1545  1997  John Smoltz  Pitcher          ATL   15     12       12  3.02
# ...

# %%
pitchers.loc[pitchers['fip'].isnull(),:]
# Out:
#       year               name                 position         team wins  \
# 0     1973       Bruce Sutter                  Pitcher      CHC-min    3
# 1     1974       Bruce Sutter                  Pitcher      CHC-min    2
# 2     1975       Bruce Sutter                  Pitcher      CHC-min    5
# 3     1976       Bruce Sutter                  Pitcher      CHC-min    2
# 17    1900  Christy Mathewson                  Pitcher          NFK   18
# 29    1911  Christy Mathewson                  Pitcher          NaN    3
# 58    1928     Walter Johnson                  Pitcher          NWK    0
# 82    1910     Pete Alexander                  Pitcher          SYR   29
# 104   1930     Pete Alexander                  Pitcher          DAL    1
# 126   1877     Candy Cummings   Pitcher and Outfielder          LYN    1
# 128   1903           Ed Walsh                  Pitcher          MDN   20
# 143   1919           Ed Walsh                  Pitcher          MLW    2
# ...

# %% [markdown]
# Of what we have, I'm hesitant to get rid of these counting stats. I'll leave them blank for now. They could be important if I want to manually calculate FIP (if possible) or ERA. I also don't want to delete anymore rows.

# %% [markdown]
# Worth noting, if we decide to take the average counts/rates per pitcher, we might want to not include the relievers who are in the HOF.
