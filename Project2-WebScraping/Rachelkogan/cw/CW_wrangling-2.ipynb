# %%
import numpy as np
import pandas as pd
import re

# %%
cw_2 = pd.read_csv('cw_2b.csv')
print cw_2.shape
cw_2.head()
# Out:
# (12283, 7)
#      title                  clue          date  year answer unique       day
# 2418        Smoke an e-cigarette   December 13  2016   VAPE  False   Tuesday

# %%
cw_3 = pd.read_csv('cw_3b.csv')
print cw_3.shape
cw_3.head()
# Out:
# (8644, 7)
#   title                              clue        date  year answer unique  \
# 0                         To-do list item   August 24  2016   TASK  False
# 1                      Skatepark features   August 24  2016  RAMPS  False
# 2               Something in a KFC bucket   August 24  2016   WING  False
# 3                         YouTube journal   August 24  2016   VLOG  False
# 4        Main ingredient in soubise sauce   August 24  2016  ONION  False
#
#           day
# 0   Wednesday
# 1   Wednesday
# 2   Wednesday
# 3   Wednesday
# 4   Wednesday

# %%
cw_4 = pd.read_csv('cw_4b.csv')
print cw_4.shape
cw_4.head()
# Out:
# (9041, 7)
#   title                       clue       date  year       answer unique  \
# 0          Too-clever-by-half type   April 22  2016  SMARTYPANTS  False
# 1            Important school fig.   April 22  2016          GPA  False
# 2           Taunt to a head-turner   April 22  2016  MADEYOULOOK   True
# 3                      Head-butter   April 22  2016          RAM  False
# 4        Make an Amazon visit, say   April 22  2016  ORDERONLINE   True
#
#        day
# 0   Friday
# 1   Friday
# 2   Friday
# 3   Friday
# 4   Friday

# %%
cw_5 = pd.read_csv('cw_5b.csv')
print cw_5.shape
cw_5.head()
# Out:
# (8718, 7)
#   title                                  clue          date  year answer  \
# 0        Airport with many connecting flights   December 29  2015    HUB
# 1                               Marquee names   December 29  2015  STARS
# 2                             Small jazz band   December 29  2015  COMBO
# 3                    Dr. J's first pro league   December 29  2015    ABA
# 4                            Screeching baby?   December 29  2015  OWLET
#
#   unique       day
# 0  False   Tuesday
# 1  False   Tuesday
# 2  False   Tuesday
# 3  False   Tuesday
# 4  False   Tuesday

# %%
cw_6 = pd.read_csv('cw_6b.csv')
print cw_6.shape
cw_6.head()
# Out:
# (8890, 7)
#   title                                   clue        date  year  answer  \
# 0                Place to lead a private life?   August 21  2015    BASE
# 1                       Armstrong contemporary   August 21  2015  ALDRIN
# 2        Daisy's husband in "The Great Gatsby"   August 21  2015     TOM
# 3                          Call girl employer?   August 21  2015    AVON
# 4                                   Sea menace   August 21  2015  PIRATE
#
#   unique      day
# 0  False   Friday
# 1  False   Friday
# 2  False   Friday
# 3  False   Friday
# 4  False   Friday

# %%
cw_7 = pd.read_csv('cw_7b.csv')
print cw_7.shape
cw_7.head()
# Out:
# (8898, 7)
#            title                              clue       date  year  answer  \
# 0  WHICH IS WISH      Rye, N.Y., or Fort Lee, N.J.   April 26  2015  SUBURB
# 1  WHICH IS WISH  Like some photographs and cliffs   April 26  2015  SCALED
# 2  WHICH IS WISH                   Bouquet tossers   April 26  2015  BRIDES
# 3  WHICH IS WISH                   Means of access   April 26  2015  AVENUE
# 4  WHICH IS WISH   Viola's love in "Twelfth Night"   April 26  2015  ORSINO
#
#   unique      day
# 0  False   Sunday
# 1  False   Sunday
# 2  False   Sunday
# 3  False   Sunday
# 4  False   Sunday

# %%
cw_8 = pd.read_csv('cw_8b.csv')
print cw_8.shape
cw_8.head()
# Out:
# (9096, 7)
#   title                        clue          date  year answer unique  \
# 0                             Homey   December 17  2014   DAWG  False
# 1              Talks like a tosspot   December 17  2014  SLURS  False
# 2                 Corp. money execs   December 17  2014   CFOS  False
# 3        Subject of a court bargain   December 17  2014   PLEA  False
# 4             Spicy Eastern cuisine   December 17  2014  HUNAN  False
#
#           day
# 0   Wednesday
# 1   Wednesday
# 2   Wednesday
# 3   Wednesday
# 4   Wednesday

# %%
cw_9 = pd.read_csv('cw_9b.csv')
print cw_9.shape
cw_9.head()
# Out:
# (8838, 7)
#   title                         clue        date  year           answer  \
# 0                     Eurasian plain   August 13  2014           STEPPE
# 1             Sugary punch, slangily   August 13  2014         BUGJUICE
# 2                        Like McJobs   August 13  2014           MENIAL
# 3        Worker's advocate, in brief   August 13  2014         UNIONREP
# 4            Class for the hotheaded   August 13  2014  ANGERMANAGEMENT
#
#   unique         day
# 0  False   Wednesday
# 1  False   Wednesday
# 2  False   Wednesday
# 3  False   Wednesday
# 4  False   Wednesday

# %%
cw_10 = pd.read_csv('cw_10b.csv')
print cw_10.shape
cw_10.head()
# Out:
# (9328, 7)
#   title                 clue       date  year answer unique       day
# 0               Sticks (out)   April 29  2014   JUTS  False   Tuesday
# 1            Cocoon contents   April 29  2014   PUPA  False   Tuesday
# 2              More balanced   April 29  2014  SANER  False   Tuesday
# 3        Man's Brest friend?   April 29  2014   AMIE  False   Tuesday
# 4                       Atop   April 29  2014   UPON  False   Tuesday

# %%
cw_11 = pd.read_csv('cw_11b.csv')
print cw_11.shape
cw_11.head()
# Out:
# (8982, 7)
#   title                              clue          date  year answer unique  \
# 0                            Good ol' boy   December 18  2013  BUBBA  False
# 1        Airport security worker's device   December 18  2013   WAND  False
# 2                        Black, to a bard   December 18  2013   EBON  False
# 3                        Composer Copland   December 18  2013  AARON  False
# 4               Outermost Aleutian island   December 18  2013   ATTU  False
#
#           day
# 0   Wednesday
# 1   Wednesday
# 2   Wednesday
# 3   Wednesday
# 4   Wednesday

# %%
cw_12 = pd.read_csv('cw_12b.csv')
print cw_12.shape
cw_12.head()
# Out:
# (8944, 7)
#       title                         clue        date  year         answer  \
# 0  EDGINESS  It may come down in a storm   August 18  2013  TELEPHONELINE
# 1  EDGINESS   Divider in a musical score   August 18  2013        BARLINE
# 2  EDGINESS             Hang-out locale?   August 18  2013    CLOTHESLINE
# 3  EDGINESS   Wrote a couple of letters?   August 18  2013      INITIALED
# 4  EDGINESS               Montral street   August 18  2013            RUE
#
#   unique      day
# 0   True   Sunday
# 1   True   Sunday
# 2  False   Sunday
# 3  False   Sunday
# 4  False   Sunday

# %%
cw_13 = pd.read_csv('cw_13b.csv')
print cw_13.shape
cw_13.head()
# Out:
# (9099, 7)
#   title                                               clue       date  year  \
# 0                                    "This bag is not ___"   April 18  2013
# 1                                    Figures in statistics   April 18  2013
# 2                         Film resident of Crab Key Island   April 18  2013
# 3                                              Apple, e.g.   April 18  2013
# 4        Instrument bearing the coat of arms of France'...   April 18  2013
#
#   answer unique        day
# 0   ATOY  False   Thursday
# 1  MODES  False   Thursday
# 2   DRNO  False   Thursday
# 3   POME  False   Thursday
# 4  AMATI  False   Thursday

# %%
cw_14 = pd.read_csv('cw_14b.csv')
print cw_14.shape
cw_14.head()
# Out:
# (8675, 7)
#   title                 clue          date  year answer unique        day
# 0           One of the folks   December 27  2012   POPS  False   Thursday
# 1        Bit the bullet, say   December 27  2012  ATEIT  False   Thursday
# 2                 French ___   December 27  2012   KISS  False   Thursday
# 3          Shoveler's target   December 27  2012   SNOW  False   Thursday
# 4         XC60, XC70 or XC90   December 27  2012  VOLVO  False   Thursday

# %%
cw_15 = pd.read_csv('cw_15b.csv')
print cw_15.shape
cw_15.head()
# Out:
# (8672, 7)
#   title                                               clue        date  year  \
# 0                         Actress Rachel of "The Notebook"   August 31  2012
# 1        Newsman who famously defined news as "somethin...   August 31  2012
# 2        ___ Avenue (Monopoly property landed on the most)   August 31  2012
# 3                                                  Ascribe   August 31  2012
# 4                                                 Big mess   August 31  2012
#
#      answer unique      day
# 0   MCADAMS  False   Friday
# 1    HEARST  False   Friday
# 2  ILLINOIS  False   Friday
# 3    IMPUTE  False   Friday
# 4  RATSNEST  False   Friday

# %%
cw = pd.concat([cw_2, cw_3, cw_4, cw_5, cw_6, cw_7, cw_8, cw_9, cw_10, cw_11, cw_12, cw_13, cw_14, cw_15], 
               ignore_index=True)
print cw.shape
cw.dropna(inplace=True)
print cw.shape
cw.head()
# Out:
# (128108, 7)
# (128101, 7)
#   title                            clue          date  year     answer unique  \
# 0          ___ Nast, publisher of Vogue   December 16  2016      CONDE  False
# 1                                  Baby   December 16  2016      SPOIL  False
# 2                    Voodoo doll action   December 16  2016        HEX  False
# 3        "Robin ___" (old Irish ballad)   December 16  2016      ADAIR  False
# 4                    Bittersweet spread   December 16  2016  MARMALADE  False
#
#        day
# 0   Friday
# 1   Friday
# 2   Friday
# 3   Friday
# 4   Friday

# %%
cw['answer'].value_counts()
vals = pd.DataFrame(cw['answer'].value_counts()).reset_index()

vals.columns = ['answer', 'answer_count']
vals.head()
# Out:
#   answer  answer_count
# 0    ERA           100
# 1    ORE            88
# 2    ONE            81
# 3    ALE            75
# 4    SPA            74

# %%
#find high-frequency words
freq = cw['answer'].value_counts()

high_freq_words = freq[freq.values > 30]

# %%
cw_high_freq = cw[cw['answer'].isin(list(high_freq_words.index))]    

high_freq_dict = dict.fromkeys(list(high_freq_words.index), [])

cw_high_freq.head()
# Out:
#    title                                               clue          date  \
# 36                                 Ivanka's younger brother   December 16
# 39                             Crash-prone "Catch-22" pilot   December 16
# 43        Setting for paintings by Tintoretto and Hieron...   December 16
# 74                                       Like some accounts    December 8
# 91                                        Prefix with -sect    December 8
#
#     year answer unique        day
# 36  2016   ERIC  False     Friday
# 39  2016    ORR  False     Friday
# 43  2016   EDEN  False     Friday
# 74  2016   ORAL  False   Thursday
# 91  2016    TRI  False   Thursday

# %%
cw = pd.merge(left=cw, right=vals, how='left', on='answer')
cw['answer_count']=cw['answer_count'].map(lambda x: int(x))
cw.head()
# Out:
#   title                            clue          date  year     answer unique  \
# 0          ___ Nast, publisher of Vogue   December 16  2016      CONDE  False
# 1                                  Baby   December 16  2016      SPOIL  False
# 2                    Voodoo doll action   December 16  2016        HEX  False
# 3        "Robin ___" (old Irish ballad)   December 16  2016      ADAIR  False
# 4                    Bittersweet spread   December 16  2016  MARMALADE  False
#
#        day  answer_count
# 0   Friday             3
# 1   Friday             4
# 2   Friday             6
# 3   Friday             4
# 4   Friday             1

# %%
cw.to_csv('cw_full.csv')

# %%
for word in list(high_freq_words.index):
    high_freq_dict[word] = list(cw_high_freq[cw_high_freq['answer']==word]['clue'])

# %%
for key in high_freq_dict:
    print key, high_freq_dict[key]
    print 
    print
# Out:
# SIS ['Girl in the fam', '"___ boom bah!"', 'Lisa, to Bart', "Bro's sibling", 'Mom-to-aunt term', 'Paige, to Jason, in "FoxTrot"', "Bro's sibling", 'What Khlo might call Kim', 'Family nickname', 'Family member, for short', 'Fam. member', 'Potential aunt, for short', 'Dot, to Ditto, in "Hi and Lois"', "Bro's sibling", 'Family moniker', 'A tot may have a big one', 'Beyonc, to Solange, or vice versa', 'One sharing a bunk bed, maybe', 'Family nickname', 'Household name?', 'Family pet name', "Bro's sib", 'One of a pair of fraternal twins, maybe', 'Certain sib', 'Start of a cheer', 'She often wears hand-me-downs', 'Start of a cheer', 'Family moniker', 'Family nickname', 'Family member, informally', "Bro's sibling"]
#
#
# ...

# %%
#when the same clues are used for diff words!
print cw.shape

cw.head()
# Out:
# (128101, 8)
#   title                            clue          date  year     answer unique  \
# 0          ___ Nast, publisher of Vogue   December 16  2016      CONDE  False
# 1                                  Baby   December 16  2016      SPOIL  False
# 2                    Voodoo doll action   December 16  2016        HEX  False
# 3        "Robin ___" (old Irish ballad)   December 16  2016      ADAIR  False
# 4                    Bittersweet spread   December 16  2016  MARMALADE  False
#
#        day  answer_count
# 0   Friday             3
# 1   Friday             4
# 2   Friday             6
# 3   Friday             4
# 4   Friday             1

# %%
cw['clue'].value_counts()
# Out:
# Mauna ___                                                  23
# Nonsense                                                   20
# -                                                          19
# Somewhat                                                   16
# Like                                                       15
# "Phooey!"                                                  15
# Fix                                                        15
# See 17-Across                                              14
# Up                                                         14
# Numerical prefix                                           14
# Pass                                                       14
# Total                                                      14
# See 1-Across                                               14
# Out                                                        13
# In                                                         13
# ...

# %%
#find high-frequency clues
freq_clues = cw['clue'].value_counts()

high_freq_clues = freq_clues[freq_clues.values > 5]
len(high_freq_clues)
# Out:
# 408

# %%
cw_high_freq_clues = cw[cw['clue'].isin(list(high_freq_clues.index))]    

high_freq_clues_dict = dict.fromkeys(list(high_freq_clues.index), [])

cw_high_freq_clues
# Out:
#                 title                     clue           date  year  \
# 44                                     Gen ___    December 16  2016
# 94                                        Jerk     December 8  2016
# 132                                 Concerning     December 8  2016
# 134                                       Goof     December 8  2016
# 142                                      Loads     December 8  2016
# 216                           Words to live by    December 15  2016
# 224                                      Spoil    December 15  2016
# 285                                       Tell    December 15  2016
# 287                                   Middling    December 15  2016
# 348                    Dermatologist's concern     December 7  2016
# 355                                        Zip     December 7  2016
# 356                                        Zip     December 7  2016
# 358                                         Up     December 7  2016
# ...

# %%
for clue in list(high_freq_clues.index):
    high_freq_clues_dict[clue] = list(cw_high_freq_clues[cw_high_freq_clues['clue']==clue]['answer'])

# %%
for key in high_freq_clues_dict:
    print key, ':', np.unique(high_freq_clues_dict[key])
    print 
    print
# Out:
# Perfect : ['EXACT' 'HONE' 'IDEAL' 'UTOPIAN']
#
#
# ___ chi : ['TAI']
#
#
# Appear : ['BESEEN' 'SEEM']
#
#
# Fit : ['ABLE' 'HALE' 'INSHAPE' 'SPASM' 'TONED']
#
#
# Fix : ['ALTER' 'MEND' 'NEUTER' 'RIG' 'SET' 'SPAY']
#
#
# Fitting : ['APROPOS' 'APT' 'DUE']
#
#
# Santa ___, Calif. : ['ANA' 'CLARA' 'ROSA']
#
#
# Surrounded by : ['AMID' 'AMIDST']
#
#
# Historical period : ['AGE' 'EPOCH' 'ERA']
#
#
# Smart-alecky : ['CUTE' 'PERT' 'SASSY' 'WISE']
#
#
# Dodge : ['ELUDE' 'EVADE']
#
#
# German article : ['DER' 'EIN' 'EINE' 'EINEN' 'EINES']
#
#
# See 10-Across : ['2PIR' 'AWAY' 'BIN' 'CIRCLE' 'NEEDISLOVE' 'PIRSQUARED' 'ROW']
#
#
# Golfer Aoki : ['ISAO']
#
#
# Wee : ['EENSY' 'MINIATURE' 'SMALL' 'TEENSY' 'TINY']
#
#
# Slightly : ['ABIT' 'ATAD' 'AWEEBIT']
#
#
# All over again : ['ANEW']
#
#
# Put off : ['ALIENATE' 'ALIENATED' 'DEFER' 'FAZE' 'TABLE']
#
#
# Neither's partner : ['NOR']
#
#
# "___-haw!" : ['YEE']
#
#
# African antelope : ['ELAND' 'GNU' 'ORYX']
#
#
# ...

# %%
oed = pd.read_csv('oed.csv')
oed.head()
# Out:
#        entry_type  year part_of_speech                   word month
# 0  new word entry  2015             n.  Antikythera mechanism  June
# 1  new word entry  2015           int.                    arr  June
# 2  new word entry  2015             n.                  audax  June
# 3  new word entry  2015             v.               autotune  June
# 4  new word entry  2015           adj.              autotuned  June

# %%
oed['entry_type']=oed['entry_type'].map(str)
oed['word']=oed['word'].map(str)
oed['month']=oed['month'].map(str)
oed['year']=oed['year'].map(str)
oed['part_of_speech']=oed['part_of_speech'].map(str)
oed.head()
# Out:
#        entry_type  year part_of_speech                   word month
# 0  new word entry  2015             n.  Antikythera mechanism  June
# 1  new word entry  2015           int.                    arr  June
# 2  new word entry  2015             n.                  audax  June
# 3  new word entry  2015             v.               autotune  June
# 4  new word entry  2015           adj.              autotuned  June

# %%
oed['cword'] = oed['word'].map(lambda x: re.sub(pattern='[ -]', repl='', string=x).upper())
oed.head()
# Out:
#        entry_type  year part_of_speech                   word month  \
# 0  new word entry  2015             n.  Antikythera mechanism  June
# 1  new word entry  2015           int.                    arr  June
# 2  new word entry  2015             n.                  audax  June
# 3  new word entry  2015             v.               autotune  June
# 4  new word entry  2015           adj.              autotuned  June
#
#                   cword
# 0  ANTIKYTHERAMECHANISM
# 1                   ARR
# 2                 AUDAX
# 3              AUTOTUNE
# 4             AUTOTUNED

# %%
#find intersection of nyt cw and oed

common_words = set(oed['cword']).intersection(cw['answer'])
print len(common_words)
common_words
# Out:
# 87
# {'ARAB',
#  'ARR',
#  'AUPAIR',
#  'AUTOTUNE',
#  'BEAUTY',
#  'BEST',
#  'BLURAY',
#  'BUFF',
#  'BURGESS',
#  'CASE',
#  'CATTY',
#  'CHICA',
#  'CIS',
#  'COMMIT',
#  'COOT',
#  'CREAMPIE',
#  'DAP',
#  'DAYTON',
#  'DISC',
#  'DISCO',
#  'DOUBLEDOUBLE',
#  'EARTOEAR',
#  'EARWORM',
#  'ECIG',
#  'ECIGARETTE',
#  'EMOJI',
#  'ERIS',
#  'EYEROLLING',
#  'FAVA',
#  'FLEXAGON',
#  'GDAY',
#  'GOFORBROKE',
#  'GOFORIT',
#  'GOING',
#  'GRAM',
#  'GRAMPS',
#  'GRAMS',
#  'GUAC',
#  'H2O',
#  'HAP',
#  'HASH',
#  'HE',
#  'HEAL',
#  'HEX',
#  'HIS',
#  'HOTMESS',
#  'HOVERBOARD',
#  'ILE',
#  'IRONFIST',
#  'ISA',
#  'JAVASCRIPT',
#  'LASTING',
#  'LOCAVORE',
#  'MARCOPOLO',
#  'MEH',
#  'OSHA',
#  'PHOTOBOMB',
#  'RESOUNDED',
#  'RESTED',
#  'RETWEET',
#  'SANGER',
#  'SCENE',
#  'SELFIE',
#  'SEXT',
#  'SHIP',
#  'SKORT',
#  'SKYPE',
#  'SLEDGE',
#  'STANK',
#  'STAYCATION',
#  'STIRFRY',
#  'STORYBOARD',
#  'STRUCTURAL',
#  'STYLO',
#  'TANLINE',
#  'TEAPARTIER',
#  'TELLY',
# ...

# %%
cw[(cw['answer']=='IMP') | (cw['answer']=='IMPS')]
# Out:
#                                title  \
# 427                        RETRONYMS
# 5216                TAKING THE FIFTH
# 9751
# 11998
# 15989
# 18692
# 24578                  DON'T SUE US!
# 29010
# 30012             POLITICAL PROMISES
# 31587
# 34323
# 39069
# 42787
# 46287
# 48370                   NON-STARTERS
# 55007
# 59423
# 60196
# 63389
# 63509
# 68916                   MOVING PARTS
# 71598
# 72705
# 74214
# 80001
# 80804
# 83994
# 86582   SHOULD I CALL THE REPAIRMAN?
# 87147
# 87189
# 87790
# 94394
# 96328
# 108198
# 112136
#
#                                                      clue           date  \
# 427     Nickname of a "Game of Thrones" dwarf, with "the"    December 11
# 5216                                        Small handful       March 12
# 9751                           Dennis the Menace, for one     January 24
# 11998                                Little troublemakers      January 2
# 15989                            World of Warcraft figure         July 8
# ...

# %%
cw[cw['clue'].map(lambda x: re.search(pattern='Game of Thrones', string=x)!= None)]
# Out:
#                      title                                               clue  \
# 8                                         Actress Headey of "Game of Thrones"
# 160                                              "Game of Thrones" and others
# 167                             Patriarch of House Stark on "Game of Thrones"
# 427              RETRONYMS  Nickname of a "Game of Thrones" dwarf, with "the"
# 1784     A CENTURY OF SONG           Elder Lannister son on "Game of Thrones"
# 8606                                  Ned's adoptive son on "Game of Thrones"
# 14816                                       "Game of Thrones" actress Chaplin
# 16367                                            Chaplin of "Game of Thrones"
# 20183                                               "Game of Thrones" network
# 20509     TRAPPED MOISTURE                       Chaplin of "Game of Thrones"
# 28100         INITIAL TURN                   "Game of Thrones" actress Dormer
# ...

# %%
cw[cw['clue'].map(lambda x: re.match(pattern='["]', string=x)!= None)].head(200)
# Out:
#                     title                                               clue  \
# 54                                               "Let's see what you've got"
# 71                                                              "For shame!"
# 92                                                             "That hurts!"
# 122                                                           "You said it!"
# 124                                                               "So what?"
# 130                        "I will speak daggers to her, but ___ none": H...
# 143                                                               "Finally!"
# 160                                             "Game of Thrones" and others
# 168                                                        "___ believe ..."
# 189                                                  "It's not my first ___"
# 194                                                          "___ boom bah!"
# ...

# %%
cw[(cw['answer']=='HBO') ]
# Out:
#                      title                        clue           date  year  \
# 9624                            "True Detective" airer     January 19  2017
# 20183                        "Game of Thrones" network         May 11  2016
# 35661                                 27-Down offering      October 7  2015
# 38906                            Where to find "Girls"      August 21  2015
# 42156                          "Game of Thrones" airer         July 8  2015
# 49137   FILL-IN-THE-BLANKS     "Game of Thrones" airer    December 28  2014
# 72537                                   "Veep" channel         June 4  2014
# 75040                                     "Girls" home       April 11  2014
# 76152                                     "Veep" airer       March 29  2014
# 78232                        "Game of Thrones" network        March 5  2014
# 88201          WHO'S LEFT?      "The Newsroom" channel     October 27  2013
# ...

# %%
cw[(cw['answer']=='UBER') ]
# Out:
#                        title                                             clue  \
# 148                                      Company whose business is picking up
# 4608                                   Company investing in self-driving cars
# 17341   ATTENDING PHYSICIANS                             Alternative to a cab
# 17669                                                         Lyft competitor
# 24769                                                Foe of the taxi industry
# 27526                                                      Competitor of Lyft
# 30662                                            Modern alternative to a taxi
# 32128                                                         Lyft competitor
# 34472                                                      Really, informally
# 38239                                       Transportation competitor of Lyft
# 60945                                          Modern cab service alternative
# ...
