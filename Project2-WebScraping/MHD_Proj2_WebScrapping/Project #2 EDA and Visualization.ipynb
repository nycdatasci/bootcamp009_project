# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency
import re
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_rows",10000)
pd.set_option("display.max_columns",100)

# %%
fiverr = pd.read_csv("./all_data.csv")

# %%
fiverr.shape
# Out:
# (16403, 12)

# %%
fiverr.head(2)
# Out:
#    category                                 rating starting_price  \
# 0  Business  rating-circles star-rating-s12 rate-9             $5
# 1  Business  rating-circles star-rating-s12 rate-9             $5
#
#          subcategory         language  \
# 0  Branding Services  English, French
# 1  Branding Services    English, Urdu
#
#                                                title  \
# 0  I will create 10 POWERFUL slogans, headlines o...
# 1    I will suggest 10 brand names for your business
#
#                                                  url          seller  \
# 0  https://www.fiverr.com/perfectionist0/create-1...  perfectionist0
# 1  https://www.fiverr.com/seotalent/suggest-10-br...       seotalent
#
#   pos_rating num_reviews       location ave_reponse_time
# 0        98%        (20)  United States           1 Hrs.
# 1        96%       (646)       Pakistan           1 Hrs.

# %%
# Getting the star-rating from the rating variable as a float

star_ratings = []

for i in range(len(fiverr.rating)):
    try:
        star_ratings.append(float(fiverr.rating[i][fiverr.rating[i].find("rate-") + 5:])/2.0)
    except:
        star_ratings.append(np.nan)

fiverr["star_rating"] = star_ratings

len(star_ratings)
# Out:
# 16403

# %%
# Cleaning the num_reviews variable by removind "()" and "-" from the number of reviews and converting to a float

num_reviews_clean = []

for i in range(len(fiverr.num_reviews)):
    if type(fiverr.num_reviews[i]) == float:
        num_reviews_clean.append(fiverr.num_reviews[i])
    else:
        num_reviews_clean.append(float(re.sub("[^\.\w]", "", fiverr.num_reviews[i])))

fiverr["num_reviews_clean"] = num_reviews_clean    

len(num_reviews_clean)
# Out:
# 16403

# %%
# Cleaning the ave_response_time variable by removing "Hrs" and converting the response time to a float 

ave_resptime_hrs = []

for i in range(len(fiverr.ave_reponse_time)):
    if type(fiverr.ave_reponse_time[i]) == float:
        ave_resptime_hrs.append(fiverr.ave_reponse_time[i])
    else:
        ave_resptime_hrs.append(float(re.sub("[^0-9]", "", fiverr.ave_reponse_time[i])))

fiverr["ave_response_time_hrs"] = ave_resptime_hrs    

len(ave_resptime_hrs)
# Out:
# 16403

# %%
# Cleaning the pos_rating variable by removing "%" and converting to a float

pos_rating_percent = []

for i in range(len(fiverr.pos_rating)):
    if type(fiverr.pos_rating[i]) == float:
        pos_rating_percent.append(fiverr.pos_rating[i])
    else:
        pos_rating_percent.append(float(re.sub("[^0-9]", "", fiverr.pos_rating[i])))

fiverr["pos_rating_percent"] = pos_rating_percent    

len(pos_rating_percent)
# Out:
# 16403

# %%
# Cleaning the pos_rating variable by removing "%" and converting to a float

starting_price_dollar = []

for i in range(len(fiverr.starting_price)):
    if type(fiverr.starting_price[i]) == float:
        starting_price_dollar.append(fiverr.starting_price[i])
    else:
        starting_price_dollar.append(float(re.sub("[^0-9]", "", fiverr.starting_price[i])))

fiverr["starting_price_dollar"] = starting_price_dollar    

len(starting_price_dollar)
# Out:
# 16403

# %%
# Finding observation with missing location

for x in fiverr.loc[fiverr.location.isnull(), ].url:
    print x
    
fiverr.loc[fiverr.location.isnull(), ]
# Out:
# https://www.fiverr.com/thanh0606/give-you-tee-spring-domination-video-course?context=adv.cat_8.subcat_26&context_type=rating&source=gallery-listing&ref_ctx_id=576247fc-d2b3-430c-b262-d9371e3ed5dd&filtered_price=&pckg_id=1&pos=21&funnel=13a2b56d-48fe-4d07-8465-51e00a43e76f
#        category                                  rating starting_price  \
# 15460  Business  rating-circles star-rating-s12 rate-10           $15
#
#          subcategory language  \
# 15460  Business Tips  English
#
#                                                    title  \
# 15460  I will give You Tee Spring Domination For Dummies
#
#                                                      url     seller  \
# 15460  https://www.fiverr.com/thanh0606/give-you-tee-...  thanh0606
#
#       pos_rating num_reviews location ave_reponse_time  star_rating  \
# 15460        99%       -18.0      NaN           1 Hrs.          5.0
#
#        num_reviews_clean  ave_response_time_hrs  pos_rating_percent  \
# 15460               18.0                    1.0                99.0
#
#        starting_price_dollar
# 15460                   15.0

# %%
# Finding observation with "Unknown" location

fiverr.loc[fiverr.location == "Unknown", ]
# Out:
#                  category                                  rating  \
# 242     Digital Marketing  rating-circles star-rating-s12 rate-10
# 436       Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 437       Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 454       Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 504     Digital Marketing   rating-circles star-rating-s12 rate-9
# 524       Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 612    Programming & Tech  rating-circles star-rating-s12 rate-10
# 1331    Digital Marketing  rating-circles star-rating-s12 rate-10
# 1419      Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 1704      Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 1798    Graphics & Design  rating-circles star-rating-s12 rate-10
# 1892    Graphics & Design  rating-circles star-rating-s12 rate-10
# 3841    Digital Marketing  rating-circles star-rating-s12 rate-10
# 4229   Programming & Tech   rating-circles star-rating-s12 rate-9
# 5670    Graphics & Design  rating-circles star-rating-s12 rate-10
# 6118    Digital Marketing  rating-circles star-rating-s12 rate-10
# 6273             Business  rating-circles star-rating-s12 rate-10
# 6377    Digital Marketing  rating-circles star-rating-s12 rate-10
# 6691   Programming & Tech  rating-circles star-rating-s12 rate-10
# 7110    Graphics & Design  rating-circles star-rating-s12 rate-10
# 7290    Graphics & Design   rating-circles star-rating-s12 rate-9
# 8255    Digital Marketing  rating-circles star-rating-s12 rate-10
# 8712             Business   rating-circles star-rating-s12 rate-9
# 9506    Graphics & Design  rating-circles star-rating-s12 rate-10
# 10029   Graphics & Design  rating-circles star-rating-s12 rate-10
# 10846   Digital Marketing  rating-circles star-rating-s12 rate-10
# 11127   Digital Marketing  rating-circles star-rating-s12 rate-10
# 12043   Video & Animation  rating-circles star-rating-s12 rate-10
# 12518   Video & Animation  rating-circles star-rating-s12 rate-10
# 12999   Video & Animation   rating-circles star-rating-s12 rate-9
# 13172       Music & Audio   rating-circles star-rating-s12 rate-9
# 13262   Video & Animation  rating-circles star-rating-s12 rate-10
# 13320   Video & Animation  rating-circles star-rating-s12 rate-10
# 13347       Music & Audio  rating-circles star-rating-s12 rate-10
# 13495       Music & Audio  rating-circles star-rating-s12 rate-10
# 13811       Music & Audio  rating-circles star-rating-s12 rate-10
# 14290       Music & Audio  rating-circles star-rating-s12 rate-10
# 14534     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 14535     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 14549     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 14553     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 14554     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 15115       Music & Audio  rating-circles star-rating-s12 rate-10
# 15120       Music & Audio   rating-circles star-rating-s12 rate-8
# 15315     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 15325     Fun & Lifestyle  rating-circles star-rating-s12 rate-10
# 15380  Programming & Tech  rating-circles star-rating-s12 rate-10
#
#       starting_price                  subcategory  \
# 242              $10                          SEO
# 436              $60          Spiritual & Healing
# 437               $5          Spiritual & Healing
# 454               $5  Health, Nutrition & Fitness
# 504               $5                          SEO
# 524               $5          Spiritual & Healing
# 612              $15       Website Builders & CMS
# 1331              $5         Influencer Marketing
# 1419              $5  Health, Nutrition & Fitness
# 1704              $5         Astrology & Readings
# 1798              $5               Vector Tracing
# 1892              $5               Vector Tracing
# 3841              $5               Local Listings
# 4229              $5                    Ecommerce
# 5670              $5          Social Media Design
# 6118              $5                  Web Traffic
# 6273              $5                Business Tips
# 6377              $5              Video Marketing
# 6691              $5              Web Programming
# 7110              $5            Photoshop Editing
# 7290              $5            Photoshop Editing
# 8255              $5                  Web Traffic
# 8712              $5             Legal Consulting
# 9506              $5                   Banner Ads
# 10029             $5      Book Covers & Packaging
# 10846             $5       Social Media Marketing
# 11127             $5       Social Media Marketing
# 12043             $5    Editing & Post Production
# 12518            $10         Lyric & Music Videos
# 12999            $10         Lyric & Music Videos
# 13172             $5                Sound Effects
# 13262             $5    Editing & Post Production
# 13320             $5      Intros & Animated Logos
# 13347             $5                Sound Effects
# 13495             $5                Sound Effects
# 13811             $5                Sound Effects
# 14290             $5                Sound Effects
# 14534             $5          Spiritual & Healing
# 14535             $5          Spiritual & Healing
# 14549             $5          Spiritual & Healing
# 14553             $5          Spiritual & Healing
# 14554             $5          Spiritual & Healing
# 15115             $5              Jingles & Drops
# 15120             $5              Jingles & Drops
# 15315            $5           Spiritual & Healing
# 15325            $5           Spiritual & Healing
# 15380           $20        Website Builders & CMS
#
#                                           language  \
# 242                                        English
# 436                                        English
# 437                                        English
# 454                                        English
# 504                       English, French, Spanish
# 524                                        English
# 612                                        English
# 1331          English, Ukrainian, Russian, Persian
# 1419                                       English
# 1704                                       English
# 1798                English, English (uk), Walloon
# 1892                                       English
# 3841                               French, English
# 4229                                       English
# 5670              English, French, Spanish, German
# 6118                      English, Spanish, French
# 6273                              English, Spanish
# 6377                      English, French, Spanish
# 6691                                       English
# 7110                                       English
# 7290                English, English (uk), Walloon
# 8255                                       English
# 8712                                       English
# 9506              English, French, Spanish, German
# 10029                                      English
# 10846  English, French, Portuguese (brasil), Dutch
# 11127              English, Italian, German, Dutch
# 12043                                      English
# 12518                    English, Italian, Russian
# 12999                                      English
# 13172                              English, German
# 13262                     English, Spanish, French
# 13320        Spanish, Portuguese (brasil), English
# 13347                              English, German
# 13495                              English, German
# 13811                              English, German
# 14290                              English, German
# 14534                                      English
# 14535                                      English
# 14549                                      English
# 14553                                      English
# 14554                                      English
# 15115                              English, German
# 15120                                      English
# 15315                                      English
# 15325                                      English
# 15380                                 English (uk)
#
#                                                    title  \
# 242      I will do 99 highpr  BACKLINKS, to your website
# 436            I will clear your karma with an Archangel
# 437                 I will do Reiki healing for your pet
# 454    I will give 101 WHITEBOARD Animation Videos in...
# 504    I will do 65,000 GSA,ser bulk,links,blast for Seo
# 524                I will remove a spirit from your home
# 612    I will design a website on Squarespace, websit...
# 1331   I will guest post for YOU on my daily Beauty blog
# 1419            I will give WEIGHTLOSS Whiteboard Videos
# 1704    I will answer ONE question from your Higher Self
# 1798             I will redraw or Vectorise logo in 24hr
# 1892       I will make your JPEG file into vector format
# 3841   I will audit and improve local business for Lo...
# 4229     I will design An eCommerce Website Online Store
# 5670          I will design a professional podcast cover
# 6118   I will provide Unlimited Targeted Website Traf...
# 6273   I will create a unique USP, elevator pitch, or...
# 6377   I will do 3in1 YouTube viral social media prom...
# 6691          I will help build and edit unique websites
# 7110   I will perform  Product Photo edit on up to 5 ...
# 7290   I will crop images and remove the background f...
# 8255   I will provide unlimited targeted,Google,traff...
# 8712   I will do consultation on UK Trademark or Trad...
# 9506   I will design a professional Website Banner an...
# 10029                 I will design an UNIQUE Book Cover
# 10846  I will do website social campaigns to 3mil soc...
# 11127  I will create social media service with my 12m...
# 12043  I will do perfect VIDEO editing ready for post...
# 12518         I will make a VINTAGE animated Music Video
# 12999  I will make a STYLISH Promotional Music Premie...
# 13172  I will deliver over 2GB samples, sound kits, a...
# 13262          I will perform PROFESSIONAL video editing
# 13320                   I will create a logo intro video
# 13347  I will deliver over 500 DJ and celebrity drops...
# 13495  I will deliver over 8000 presets for Sylenth1 ...
# 13811  I will make your vocals sound perfect by tunin...
# 14290  I will deliver 250 DJ sound effects, a lot of ...
# 14534  I will send a powerful distant Reiki healing f...
# 14535     I will cleanse your home with the Divine Light
# 14549    I will remove ALL forms of cords from your aura
# 14553           I will connect with an Archangel to heal
# 14554               I will banish and remove black magic
# 15115  I will compose an audio logo, jingle, song for...
# 15120  I will do the perfect British Female Radio dro...
# 15315  I will balance and activate your Pineal and Pi...
# 15325        I will reverse any spell using Reiki energy
# 15380                  I will design an awesome wix site
#
#                                                      url           seller  \
# 242    https://www.fiverr.com/tecnic21/do-80-highpr-b...         tecnic21
# 436    https://www.fiverr.com/shanu247/clear-your-kar...         shanu247
# 437    https://www.fiverr.com/shanu247/do-reiki-heali...         shanu247
# 454    https://www.fiverr.com/healthfitnessma/give-10...  healthfitnessma
# 504    https://www.fiverr.com/seo_runner/do-65-000-gs...       seo_runner
# 524    https://www.fiverr.com/shanu247/remove-a-spiri...         shanu247
# 612    https://www.fiverr.com/everyouth/design-a-webs...        everyouth
# 1331   https://www.fiverr.com/viikka/post-your-articl...           viikka
# 1419   https://www.fiverr.com/healthfitnessma/give-we...  healthfitnessma
# 1704   https://www.fiverr.com/shanu247/answer-one-que...         shanu247
# 1798   https://www.fiverr.com/labenajaay/redraw-or-ve...       labenajaay
# 1892   https://www.fiverr.com/artu75/make-your-jpeg-f...           artu75
# 3841   https://www.fiverr.com/anniepro/audit-and-opti...         anniepro
# 4229   https://www.fiverr.com/estore_pro/create-a-pro...       estore_pro
# 5670   https://www.fiverr.com/graphichubs/design-a-pr...      graphichubs
# 6118   https://www.fiverr.com/jademax/provide-unlimit...          jademax
# 6273   https://www.fiverr.com/livefreeretiree/write-a...  livefreeretiree
# 6377   https://www.fiverr.com/haileymichelle/do-3in1-...   haileymichelle
# 6691   https://www.fiverr.com/elliemariza/help-build-...      elliemariza
# 7110   https://www.fiverr.com/akilathisum/perform-pro...      akilathisum
# 7290   https://www.fiverr.com/vanessaprofessi/crop-im...  vanessaprofessi
# 8255   https://www.fiverr.com/mediatwitter/create-a-b...     mediatwitter
# 8712   https://www.fiverr.com/lexteamuk/do-consultati...        lexteamuk
# 9506   https://www.fiverr.com/graphichubs/design-a-pr...      graphichubs
# 10029  https://www.fiverr.com/brenda_art177/convert-y...    brenda_art177
# 10846  https://www.fiverr.com/shiningbegin/do-website...     shiningbegin
# 11127  https://www.fiverr.com/goodworkservice/create-...  goodworkservice
# 12043  https://www.fiverr.com/expert360pro/do-video-e...     expert360pro
# 12518  https://www.fiverr.com/molliganamber/make-vint...    molliganamber
# 12999  https://www.fiverr.com/brianwalltz/make-a-styl...      brianwalltz
# 13172  https://www.fiverr.com/makingmusic/deliver-ove...      makingmusic
# 13262  https://www.fiverr.com/digitaldirector/edit-yo...  digitaldirector
# 13320  https://www.fiverr.com/clinton_graphx/create-a...   clinton_graphx
# 13347  https://www.fiverr.com/makingmusic/send-you-ov...      makingmusic
# 13495  https://www.fiverr.com/makingmusic/deliver-ove...      makingmusic
# 13811  https://www.fiverr.com/makingmusic/make-your-v...      makingmusic
# 14290  https://www.fiverr.com/makingmusic/create-and-...      makingmusic
# 14534  https://www.fiverr.com/shanu247/do-a-15-minute...         shanu247
# 14535  https://www.fiverr.com/shanu247/cleanse-and-se...         shanu247
# 14549  https://www.fiverr.com/shanu247/clean-your-aur...         shanu247
# 14553  https://www.fiverr.com/shanu247/heal-you-with-...         shanu247
# 14554  https://www.fiverr.com/shanu247/banish-and-rem...         shanu247
# 15115  https://www.fiverr.com/makingmusic/compose-an-...      makingmusic
# 15120  https://www.fiverr.com/suzelah/do-the-perfect-...          suzelah
# 15315  https://www.fiverr.com/shanu247/balance-and-ac...         shanu247
# 15325  https://www.fiverr.com/shanu247/reverse-any-sp...         shanu247
# 15380  https://www.fiverr.com/kevin_ebook/design-an-a...      kevin_ebook
#
#       pos_rating num_reviews location ave_reponse_time  star_rating  \
# 242          95%        (78)  Unknown           1 Hrs.          5.0
# 436         100%        (23)  Unknown           6 Hrs.          5.0
# 437         100%        (64)  Unknown           6 Hrs.          5.0
# 454          96%        (56)  Unknown          22 Hrs.          5.0
# 504          95%        (28)  Unknown          14 Hrs.          4.5
# 524         100%        (90)  Unknown           6 Hrs.          5.0
# 612          91%         (1)  Unknown           1 Hrs.          5.0
# 1331         96%        (11)  Unknown           1 Hrs.          5.0
# 1419         96%        (16)  Unknown          22 Hrs.          5.0
# 1704        100%        (21)  Unknown           6 Hrs.          5.0
# 1798         99%        (81)  Unknown           2 Hrs.          5.0
# 1892         99%       (189)  Unknown           9 Hrs.          5.0
# 3841         99%         (8)  Unknown           5 Hrs.          5.0
# 4229         98%        (19)  Unknown           8 Hrs.          4.5
# 5670         97%        (22)  Unknown           1 Hrs.          5.0
# 6118         99%      (5955)  Unknown          13 Hrs.          5.0
# 6273         97%       (130)  Unknown           3 Hrs.          5.0
# 6377         97%         (2)  Unknown          10 Hrs.          5.0
# 6691         98%        (33)  Unknown           1 Hrs.          5.0
# 7110         99%       (412)  Unknown           1 Hrs.          5.0
# 7290         95%        (15)  Unknown           1 Hrs.          4.5
# 8255         97%        (48)  Unknown          16 Hrs.          5.0
# 8712         91%        (11)  Unknown           2 Days          4.5
# 9506         97%       (137)  Unknown           1 Hrs.          5.0
# 10029        97%       (141)  Unknown           3 Hrs.          5.0
# 10846        98%      (2185)  Unknown          11 Hrs.          5.0
# 11127        97%       (926)  Unknown          13 Hrs.          5.0
# 12043       100%        (66)  Unknown           1 Hrs.          5.0
# 12518        99%         (9)  Unknown           2 Hrs.          5.0
# 12999        99%         (2)  Unknown           3 Hrs.          4.5
# 13172        99%        (14)  Unknown           2 Hrs.          4.5
# 13262        99%       (900)  Unknown           3 Hrs.          5.0
# 13320        99%        (28)  Unknown           1 Hrs.          5.0
# 13347        99%       (309)  Unknown           2 Hrs.          5.0
# 13495        99%        (39)  Unknown           2 Hrs.          5.0
# 13811        99%         (7)  Unknown           2 Hrs.          5.0
# 14290        99%        (20)  Unknown           2 Hrs.          5.0
# 14534       100%       (789)  Unknown           6 Hrs.          5.0
# 14535       100%       (155)  Unknown           6 Hrs.          5.0
# 14549       100%       (674)  Unknown           6 Hrs.          5.0
# 14553       100%       (267)  Unknown           6 Hrs.          5.0
# 14554       100%       (525)  Unknown           6 Hrs.          5.0
# 15115        99%        (99)  Unknown           2 Hrs.          5.0
# 15120        91%         (6)  Unknown          21 Hrs.          4.0
# 15315       100%         -59  Unknown           6 Hrs.          5.0
# 15325       100%        -265  Unknown           6 Hrs.          5.0
# 15380        99%         -29  Unknown           3 Hrs.          5.0
#
#        num_reviews_clean  ave_response_time_hrs  pos_rating_percent  \
# 242                 78.0                    1.0                95.0
# 436                 23.0                    6.0               100.0
# 437                 64.0                    6.0               100.0
# 454                 56.0                   22.0                96.0
# 504                 28.0                   14.0                95.0
# 524                 90.0                    6.0               100.0
# 612                  1.0                    1.0                91.0
# 1331                11.0                    1.0                96.0
# 1419                16.0                   22.0                96.0
# 1704                21.0                    6.0               100.0
# 1798                81.0                    2.0                99.0
# 1892               189.0                    9.0                99.0
# 3841                 8.0                    5.0                99.0
# 4229                19.0                    8.0                98.0
# 5670                22.0                    1.0                97.0
# 6118              5955.0                   13.0                99.0
# 6273               130.0                    3.0                97.0
# 6377                 2.0                   10.0                97.0
# 6691                33.0                    1.0                98.0
# 7110               412.0                    1.0                99.0
# 7290                15.0                    1.0                95.0
# 8255                48.0                   16.0                97.0
# 8712                11.0                    2.0                91.0
# 9506               137.0                    1.0                97.0
# 10029              141.0                    3.0                97.0
# 10846             2185.0                   11.0                98.0
# 11127              926.0                   13.0                97.0
# 12043               66.0                    1.0               100.0
# 12518                9.0                    2.0                99.0
# 12999                2.0                    3.0                99.0
# 13172               14.0                    2.0                99.0
# 13262              900.0                    3.0                99.0
# 13320               28.0                    1.0                99.0
# 13347              309.0                    2.0                99.0
# 13495               39.0                    2.0                99.0
# 13811                7.0                    2.0                99.0
# 14290               20.0                    2.0                99.0
# 14534              789.0                    6.0               100.0
# 14535              155.0                    6.0               100.0
# 14549              674.0                    6.0               100.0
# 14553              267.0                    6.0               100.0
# 14554              525.0                    6.0               100.0
# 15115               99.0                    2.0                99.0
# 15120                6.0                   21.0                91.0
# 15315               59.0                    6.0               100.0
# 15325              265.0                    6.0               100.0
# 15380               29.0                    3.0                99.0
#
#        starting_price_dollar
# 242                     10.0
# 436                     60.0
# 437                      5.0
# 454                      5.0
# 504                      5.0
# 524                      5.0
# 612                     15.0
# 1331                     5.0
# 1419                     5.0
# 1704                     5.0
# 1798                     5.0
# 1892                     5.0
# 3841                     5.0
# 4229                     5.0
# 5670                     5.0
# 6118                     5.0
# 6273                     5.0
# 6377                     5.0
# 6691                     5.0
# 7110                     5.0
# 7290                     5.0
# 8255                     5.0
# 8712                     5.0
# 9506                     5.0
# 10029                    5.0
# 10846                    5.0
# 11127                    5.0
# 12043                    5.0
# 12518                   10.0
# 12999                   10.0
# 13172                    5.0
# 13262                    5.0
# 13320                    5.0
# 13347                    5.0
# 13495                    5.0
# 13811                    5.0
# 14290                    5.0
# 14534                    5.0
# 14535                    5.0
# 14549                    5.0
# 14553                    5.0
# 14554                    5.0
# 15115                    5.0
# 15120                    5.0
# 15315                    5.0
# 15325                    5.0
# 15380                   20.0

# %%
# Converting "Unknown" location to NAN

fiverr.loc[fiverr.location == "Unknown", "location"] = np.nan

# %%
fiverr["norm_response_time"] = fiverr.groupby("location").ave_response_time_hrs.transform(lambda x: (x - x.mean()) / x.std())
fiverr["norm_star_rating"] = fiverr.groupby("location").star_rating.transform(lambda x: (x - x.mean()) / x.std())
fiverr.head(3)
# Out:
#    category                                  rating starting_price  \
# 0  Business   rating-circles star-rating-s12 rate-9             $5
# 1  Business   rating-circles star-rating-s12 rate-9             $5
# 2  Business  rating-circles star-rating-s12 rate-10             $5
#
#          subcategory          language  \
# 0  Branding Services   English, French
# 1  Branding Services     English, Urdu
# 2  Branding Services  English, Spanish
#
#                                                title  \
# 0  I will create 10 POWERFUL slogans, headlines o...
# 1    I will suggest 10 brand names for your business
# 2  I will give you the best slogan for your business
#
#                                                  url          seller  \
# 0  https://www.fiverr.com/perfectionist0/create-1...  perfectionist0
# 1  https://www.fiverr.com/seotalent/suggest-10-br...       seotalent
# 2  https://www.fiverr.com/startselect/give-you-th...     startselect
#
#   pos_rating num_reviews       location ave_reponse_time  star_rating  \
# 0        98%        (20)  United States           1 Hrs.          4.5
# 1        96%       (646)       Pakistan           1 Hrs.          4.5
# 2        99%       (168)      Nicaragua           6 Hrs.          5.0
#
#    num_reviews_clean  ave_response_time_hrs  pos_rating_percent  \
# 0               20.0                    1.0                98.0
# 1              646.0                    1.0                96.0
# 2              168.0                    6.0                99.0
#
#    starting_price_dollar  norm_response_time  norm_star_rating
# 0                    5.0           -0.711720         -1.202023
# 1                    5.0           -0.505177         -1.721734
# 2                    5.0            0.645497               NaN

# %%
fiverr.shape
# Out:
# (16403, 19)

# %%
fiverr = fiverr.drop_duplicates()
fiverr.shape
# Out:
# (16332, 19)

# %%
# Count of observations by country 

country_df = fiverr.groupby("location").agg("count")

country_df.rating.sort_values(ascending = False).head(25)
# Out:
# location
# United States        3389
# Pakistan             2322
# India                1631
# Bangladesh            971
# Sri Lanka             688
# United Kingdom        650
# Indonesia             393
# Canada                337
# Nigeria               324
# Venezuela             317
# Romania               223
# Philippines           190
# Morocco               186
# Serbia                157
# Ukraine               156
# Australia             150
# Kenya                 136
# Germany               130
# Italy                 123
# Vietnam               113
# Israel                112
# Macedonia [FYROM]     104
# Bulgaria              103
# Netherlands           100
# Egypt                  98
# Name: rating, dtype: int64

# %%
# Count of observations that are from the US and those that are not from the US

fiverr["isUS"] = ["US" if x == "United States" else "Not-US" for x in fiverr.location]

local_or_not = fiverr.groupby("isUS").agg("count")

local_or_not.location
# Out:
# isUS
# Not-US    12611
# US         3673
# Name: location, dtype: int64

# %%
local_or_not.location.plot.bar(color = "maroon", figsize = (5,10))

plt.xlabel("Country", size = 20)
plt.ylabel("Count", size = 20)
plt.tick_params(axis='x', which='major', labelsize=15)

plt.show()

# %%
plt.figure(figsize=(16,10))
fiverr.groupby('location')['category'].agg("count").sort_values(ascending=False).head(15).plot.bar(color = "green")
plt.xlabel('Country', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.title('Freelancers by Country', fontsize = 20)
plt.show()

# %%
# Counts per category

category_df_noloc = fiverr.groupby(["category"]).location.agg("count")

for category in category_df_noloc.index:
    print category, "\n", category_df_noloc[category]
# Out:
# Advertising
# 1
# Business
# 1903
# Digital Marketing
# 2650
# Fun & Lifestyle
# 2913
# Graphics & Design
# 3822
# Music & Audio
# 1654
# Programming & Tech
# 2150
# Video & Animation
# 1191

# %%
# Removing the Avertising category since it only has one single observation

fiverr = fiverr[fiverr.category != "Advertising"]

# %%
# Counts per category

category_df_noloc = fiverr.groupby(["category"]).location.agg("count")

for category in category_df_noloc.index:
    print category, "\n", category_df_noloc[category]
# Out:
# Business
# 1903
# Digital Marketing
# 2650
# Fun & Lifestyle
# 2913
# Graphics & Design
# 3822
# Music & Audio
# 1654
# Programming & Tech
# 2150
# Video & Animation
# 1191

# %%
# Counts for each category by country

category_df = fiverr.groupby(["category", "location"]).location.agg("count")
to = 0

for category in category_df.index.levels[0]:
    print category, "\n", category_df[category].sort_values(ascending = False).head(5), "\n"
# Out:
# Business
# location
# United States    580
# Pakistan         342
# India            155
# Bangladesh       151
# Nigeria          105
# Name: location, dtype: int64
#
# Digital Marketing
# location
# United States     700
# India             414
# Pakistan          331
# Bangladesh        247
# United Kingdom    140
# Name: location, dtype: int64
#
# Fun & Lifestyle
# location
# United States     947
# India             217
# Pakistan          171
# Sri Lanka         132
# United Kingdom    124
# Name: location, dtype: int64
#
# Graphics & Design
# location
# Pakistan         763
# United States    384
# India            379
# Sri Lanka        334
# Bangladesh       333
# Name: location, dtype: int64
#
# Music & Audio
# location
# United States     669
# United Kingdom    182
# Venezuela          81
# Canada             67
# Serbia             44
# Name: location, dtype: int64
#
# Programming & Tech
# location
# Pakistan         635
# India            463
# Bangladesh       222
# United States    215
# Sri Lanka         63
# Name: location, dtype: int64
#
# Video & Animation
# location
# United States    178
# Pakistan         161
# India            143
# Sri Lanka         77
# Bangladesh        48
# Name: location, dtype: int64

# %%
# Counts per each sub-category

subcategory_df_noloc = fiverr.groupby(["subcategory"]).location.agg("count")

for subcategory in subcategory_df_noloc.index:
    print subcategory, "\n", subcategory_df_noloc[subcategory]
# Out:
# 3D & 2D Models
# 240
# Animated Characters & Modeling
# 231
# Arts & Crafts
# 235
# Astrology & Readings
# 232
# Banner Ads
# 239
# Book Covers & Packaging
# 235
# Branding Services
# 239
# Business Cards & Stationery
# 238
# Business Plans
# 239
# Business Tips
# 235
# Cartoons & Caricatures
# 239
# Celebrity Impersonators
# 48
# Content Marketing
# 240
# Data Analysis & Reports
# 241
# Databases
# 239
# Domain Research
# 238
# Ecommerce
# 239
# Editing & Post Production
# 237
# Family & Genealogy
# 48
# Financial Consulting
# 239
# Flyers & Posters
# 242
# Gaming
# 234
# Global Culture
# 239
# Greeting Cards & Videos
# 237
# Health, Nutrition & Fitness
# 235
# Illustration
# 240
# Influencer Marketing
# 237
# Infographics
# 239
# Intros & Animated Logos
# 241
# Invitations
# 237
# Jingles & Drops
# 228
# Legal Consulting
# 236
# Local Listings
# 239
# Logo Design
# 238
# Lyric & Music Videos
# 237
# Market Research
# 237
# Marketing Strategy
# 233
# Mixing & Mastering
# 238
# Mobile Advertising
# 48
# Mobile Apps & Web
# 235
# Online Lessons
# 237
# Other
# 1
# Photoshop Editing
# 238
# Pranks & Stunts
# 229
# Presentation Design
# 242
# Presentations
# 236
# Producers & Composers
# 239
# Promotional & Brand Videos
# 244
# QA
# 240
# Relationship Advice
# 238
# SEO
# 234
# Search & Display Marketing
# 236
# Session Musicians & Singers
# 237
# Singer-Songwriters
# 237
# Social Media Design
# 238
# Social Media Marketing
# 231
# Sound Effects
# 234
# Spiritual & Healing
# 231
# T-Shirts
# 240
# User Testing
# 238
# Vector Tracing
# 238
# Video Marketing
# 239
# Viral Videos
# 231
# Virtual Assistant
# 242
# Voice Over
# 240
# Web & Mobile Design
# 239
# Web Analytics
# 237
# Web Programming
# 240
# Web Traffic
# 238
# Website Builders & CMS
# 239
# Whiteboard & Explainer Videos
# 1
# WordPress
# 239
# Your Message On...
# 239

# %%
# Counts for each sub-category by country

subcategory_df = fiverr.groupby(["subcategory", "location"]).location.agg("count")

for subcategory in subcategory_df.index.levels[0]:
    print subcategory, "\n", subcategory_df[subcategory].sort_values(ascending = False).head(5), "\n"
# Out:
# 3D & 2D Models
# location
# Vietnam       41
# Pakistan      31
# India         29
# Bangladesh    19
# Venezuela     17
# Name: location, dtype: int64
#
# Animated Characters & Modeling
# location
# India            53
# United States    35
# Pakistan         33
# Sri Lanka        16
# Bangladesh        9
# Name: location, dtype: int64
#
# Arts & Crafts
# location
# United States     80
# Pakistan          22
# Sri Lanka         18
# India             17
# United Kingdom     9
# Name: location, dtype: int64
#
# Astrology & Readings
# location
# United States     110
# India              21
# United Kingdom     20
# Canada             13
# Australia           8
# Name: location, dtype: int64
#
# Banner Ads
# location
# Pakistan         44
# Sri Lanka        42
# India            33
# United States    21
# Bangladesh       21
# Name: location, dtype: int64
#
# Book Covers & Packaging
# location
# United States    40
# Pakistan         33
# India            28
# Sri Lanka        26
# Nigeria          16
# Name: location, dtype: int64
#
# Branding Services
# location
# United States     122
# Nigeria            24
# Pakistan           19
# India              12
# United Kingdom     10
# Name: location, dtype: int64
#
# Business Cards & Stationery
# location
# Pakistan         60
# Bangladesh       50
# United States    23
# India            18
# Sri Lanka        15
# Name: location, dtype: int64
#
# Business Plans
# location
# United States    87
# Pakistan         40
# Nigeria          24
# Kenya            17
# Bulgaria         11
# Name: location, dtype: int64
#
# Business Tips
# location
# United States     116
# United Kingdom     18
# Canada             14
# Nigeria             8
# India               6
# Name: location, dtype: int64
#
# Cartoons & Caricatures
# location
# Indonesia        74
# Philippines      23
# United States    19
# India            18
# Venezuela        11
# Name: location, dtype: int64
#
# Celebrity Impersonators
# location
# United States     29
# Canada             5
# United Kingdom     3
# Venezuela          2
# Sri Lanka          1
# Name: location, dtype: int64
#
# Content Marketing
# location
# India             79
# United States     50
# Pakistan          43
# United Kingdom    16
# Turkey             7
# Name: location, dtype: int64
#
# Data Analysis & Reports
# location
# Pakistan         65
# India            34
# United States    30
# Nigeria          25
# Bangladesh       14
# Name: location, dtype: int64
#
# Databases
# location
# Pakistan         94
# India            39
# United States    20
# Sri Lanka        17
# Bangladesh        8
# Name: location, dtype: int64
#
# Domain Research
# location
# United States     62
# Pakistan          49
# India             23
# Bangladesh        16
# United Kingdom    10
# Name: location, dtype: int64
#
# Ecommerce
# location
# Pakistan          59
# India             59
# Bangladesh        50
# United States     22
# United Kingdom     8
# Name: location, dtype: int64
#
# Editing & Post Production
# location
# Pakistan         37
# United States    31
# India            18
# Sri Lanka        17
# Serbia           13
# Name: location, dtype: int64
#
# Family & Genealogy
# location
# United States     22
# United Kingdom     3
# Serbia             2
# Philippines        2
# Venezuela          1
# Name: location, dtype: int64
#
# Financial Consulting
# location
# Pakistan         71
# United States    58
# India            16
# Bangladesh       15
# Nigeria          11
# Name: location, dtype: int64
#
# Flyers & Posters
# location
# Pakistan         55
# Sri Lanka        51
# Bangladesh       21
# India            21
# United States    21
# Name: location, dtype: int64
#
# Gaming
# location
# United States     73
# Canada            18
# India             13
# United Kingdom    12
# Australia         11
# Name: location, dtype: int64
#
# Global Culture
# location
# United States    48
# India            14
# Italy            12
# Thailand         12
# Sri Lanka         9
# Name: location, dtype: int64
#
# Greeting Cards & Videos
# location
# United States    58
# India            36
# Sri Lanka        26
# Ukraine          10
# Canada            9
# Name: location, dtype: int64
#
# Health, Nutrition & Fitness
# location
# United States     90
# India             16
# Pakistan          15
# United Kingdom    13
# Canada            11
# Name: location, dtype: int64
#
# Illustration
# location
# Indonesia      42
# India          22
# Pakistan       17
# Philippines    14
# Bangladesh     12
# Name: location, dtype: int64
#
# Influencer Marketing
# location
# United States    79
# Pakistan         42
# India            23
# Canada           12
# Nigeria           9
# Name: location, dtype: int64
#
# Infographics
# location
# Pakistan         83
# India            29
# Indonesia        22
# United States    16
# Venezuela        10
# Name: location, dtype: int64
#
# Intros & Animated Logos
# location
# Pakistan         39
# United States    28
# India            25
# Sri Lanka        17
# Ukraine          16
# Name: location, dtype: int64
#
# Invitations
# location
# United States    40
# Pakistan         34
# Venezuela        17
# Sri Lanka        17
# Indonesia        17
# Name: location, dtype: int64
#
# Jingles & Drops
# location
# United States     96
# United Kingdom    47
# Jamaica           13
# Venezuela         10
# Canada             8
# Name: location, dtype: int64
#
# Legal Consulting
# location
# United States     76
# Pakistan          34
# India             19
# Nigeria           15
# United Kingdom    13
# Name: location, dtype: int64
#
# Local Listings
# location
# Bangladesh        95
# United States     36
# Pakistan          35
# India             25
# United Kingdom    11
# Name: location, dtype: int64
#
# Logo Design
# location
# Pakistan          109
# Sri Lanka          36
# India              23
# United Kingdom     10
# United States       9
# Name: location, dtype: int64
#
# Lyric & Music Videos
# location
# United States     31
# Pakistan          22
# India             18
# United Kingdom    14
# Indonesia         12
# Name: location, dtype: int64
#
# Market Research
# location
# Bangladesh       64
# United States    41
# Pakistan         41
# India            32
# Nigeria          11
# Name: location, dtype: int64
#
# Marketing Strategy
# location
# United States     82
# India             24
# United Kingdom    18
# Canada            12
# Pakistan          11
# Name: location, dtype: int64
#
# Mixing & Mastering
# location
# United States     74
# United Kingdom    21
# Serbia            13
# Nigeria           12
# Venezuela         10
# Name: location, dtype: int64
#
# Mobile Advertising
# location
# Pakistan         12
# United States     9
# India             6
# Bangladesh        5
# Canada            3
# Name: location, dtype: int64
#
# Mobile Apps & Web
# location
# Pakistan         96
# India            61
# United States    15
# Bangladesh        8
# Sri Lanka         8
# Name: location, dtype: int64
#
# Online Lessons
# location
# Pakistan         62
# Kenya            33
# United States    32
# India            22
# Sri Lanka        17
# Name: location, dtype: int64
#
# Other
# location
# United Kingdom    1
# Name: location, dtype: int64
#
# Photoshop Editing
# location
# Pakistan         47
# Bangladesh       40
# United States    35
# Sri Lanka        28
# India            23
# Name: location, dtype: int64
#
# Pranks & Stunts
# location
# United States     92
# South Africa      25
# Venezuela         22
# United Kingdom     9
# India              5
# Name: location, dtype: int64
#
# Presentation Design
# location
# Pakistan         75
# United States    34
# Sri Lanka        17
# India            15
# Nigeria           9
# Name: location, dtype: int64
#
# Presentations
# location
# Pakistan          62
# United States     47
# India             28
# Bangladesh        18
# United Kingdom    12
# Name: location, dtype: int64
#
# Producers & Composers
# location
# United States     50
# Venezuela         31
# United Kingdom    20
# India             14
# Romania           12
# Name: location, dtype: int64
#
# Promotional & Brand Videos
# location
# United States    53
# Pakistan         30
# India            29
# Sri Lanka        15
# Bangladesh       12
# Name: location, dtype: int64
#
# QA
# location
# India            90
# Pakistan         50
# United States    17
# Bangladesh       17
# Sri Lanka        10
# Name: location, dtype: int64
#
# Relationship Advice
# location
# United States     122
# Pakistan           22
# United Kingdom     12
# Canada             12
# India               6
# Name: location, dtype: int64
#
# SEO
# location
# United States     51
# Pakistan          39
# India             31
# Bangladesh        20
# United Kingdom    16
# Name: location, dtype: int64
#
# Search & Display Marketing
# location
# India            68
# United States    39
# Bangladesh       21
# Pakistan         17
# Germany           8
# Name: location, dtype: int64
#
# Session Musicians & Singers
# location
# United States     83
# Canada            22
# United Kingdom    20
# Venezuela         14
# Israel            11
# Name: location, dtype: int64
#
# Singer-Songwriters
# location
# United States     118
# United Kingdom     26
# Venezuela          11
# Bulgaria            7
# Australia           6
# Name: location, dtype: int64
#
# Social Media Design
# location
# United States    36
# Sri Lanka        24
# Pakistan         24
# India            17
# Indonesia        13
# Name: location, dtype: int64
#
# Social Media Marketing
# location
# United States     64
# Pakistan          25
# Bangladesh        25
# India             18
# United Kingdom    10
# Name: location, dtype: int64
#
# Sound Effects
# location
# United States     79
# United Kingdom    19
# Serbia            11
# Canada            11
# India              8
# Name: location, dtype: int64
#
# Spiritual & Healing
# location
# United States     96
# India             23
# Canada            17
# United Kingdom     9
# Indonesia          8
# Name: location, dtype: int64
#
# T-Shirts
# location
# Bangladesh       61
# Pakistan         42
# United States    24
# Indonesia        24
# India            19
# Name: location, dtype: int64
#
# User Testing
# location
# United States     50
# India             49
# Pakistan          24
# United Kingdom    16
# Canada             9
# Name: location, dtype: int64
#
# Vector Tracing
# location
# Pakistan      59
# Indonesia     34
# Bangladesh    24
# Sri Lanka     19
# India         18
# Name: location, dtype: int64
#
# Video Marketing
# location
# United States     78
# India             36
# Pakistan          24
# Bangladesh        21
# United Kingdom    21
# Name: location, dtype: int64
#
# Viral Videos
# location
# United States    56
# Sri Lanka        32
# India            20
# Venezuela        18
# Canada            9
# Name: location, dtype: int64
#
# Virtual Assistant
# location
# Pakistan         70
# Bangladesh       46
# United States    33
# India            31
# Jamaica          12
# Name: location, dtype: int64
#
# Voice Over
# location
# United States     169
# United Kingdom     28
# Canada             12
# Australia           8
# Spain               4
# Name: location, dtype: int64
#
# Web & Mobile Design
# location
# India            53
# Pakistan         41
# United States    27
# Bangladesh       24
# Sri Lanka        13
# Name: location, dtype: int64
#
# Web Analytics
# location
# India             58
# Pakistan          33
# United States     31
# Bangladesh        27
# United Kingdom    16
# Name: location, dtype: int64
#
# Web Programming
# location
# Pakistan         81
# India            52
# Bangladesh       40
# United States    16
# Morocco           7
# Name: location, dtype: int64
#
# Web Traffic
# location
# United States     119
# Sri Lanka          49
# India              23
# Canada             10
# United Kingdom      9
# Name: location, dtype: int64
#
# Website Builders & CMS
# location
# Pakistan         76
# Bangladesh       36
# United States    34
# India            30
# Morocco           7
# Name: location, dtype: int64
#
# Whiteboard & Explainer Videos
# location
# United Kingdom    1
# Name: location, dtype: int64
#
# WordPress
# location
# Pakistan         90
# India            49
# Bangladesh       42
# United States    11
# Sri Lanka         6
# Name: location, dtype: int64
#
# Your Message On...
# location
# United States    39
# India            22
# Venezuela        19
# Sri Lanka        16
# Ukraine          10
# Name: location, dtype: int64

# %%
# Chi Square Test of Independence to test if location and category/subcategory are independent

# Chi-Square Test of Independence: Category and Location
chi2, p, ddof, expected = chi2_contingency(pd.crosstab(fiverr.category, fiverr.location))
msg = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print "Chi-Square Test of Independence: Category and Location:"
print(msg.format(chi2, p, ddof))

# Chi-Square Test of Independence: Subcategory and Location
chi2, p, ddof, expected = chi2_contingency(pd.crosstab(fiverr.subcategory, fiverr.location))
msg = "Test Statistic: {}\np-value: {}\nDegrees of Freedom: {}\n"
print "Chi-Square Test of Independence: Subcategory and Location:"
print(msg.format(chi2, p, ddof))
# Out:
# Chi-Square Test of Independence: Category and Location:
# Test Statistic: 6458.27332173
# p-value: 0.0
# Degrees of Freedom: 852
#
# Chi-Square Test of Independence: Subcategory and Location:
# Test Statistic: 27501.5005635
# p-value: 0.0
# Degrees of Freedom: 10224

# %%
# Representation by Count of Top 5 Countries in each Category

Tot = len(set(fiverr.category))
Cols = 4

# Compute Rows required

Rows = Tot // Cols 
Rows += Tot % Cols

# Create a Position index

Position = range(1,Tot + 1)

# # Create main figure

fig = plt.figure(figsize=(40, 50))

category_df = fiverr.groupby(["category", "location"]).location.agg("count")

for k in range(len(category_df.index.levels[0])):
    
    ax = fig.add_subplot(Rows, Cols, Position[k])
    category_df[category_df.index.levels[0][k]].sort_values(ascending = False).head(5).plot(kind = "bar", edgecolor ="black", color = "orange")
    plt.xlabel("\n" + 'Country', fontsize = 45)
    plt.ylabel('Count', fontsize = 45)
    plt.ylim((0,1000))
    plt.title("\n" + str(category_df.index.levels[0][k]) + "\n", fontsize = 60)
    ax.set_xticklabels([item.get_text() for item in ax.get_xticklabels()], size = 30)
    ax.tick_params(axis='y', which='major', labelsize=40)
    

plt.tight_layout()    
plt.show()

# %%
# # Representation by Percentage of Top 5 Countries in each Category

# Tot = len(set(fiverr.category))
# Cols = 4

# # Compute Rows required

# Rows = Tot // Cols 
# Rows += Tot % Cols

# # Create a Position index

# Position = range(1,Tot + 1)

# # # Create main figure

# fig = plt.figure(figsize=(40,50))

# category_df = fiverr.groupby(["category", "location"]).location.agg("count")
# test = fiverr.groupby(["category","location"])["location"].size()
# test.groupby(level = [0]).transform(sum)
# x = test / test.groupby(level = [0]).transform(sum) * 100.00
# y = x.groupby(level = 0).nlargest(5)


# for k in range(len(y.index.levels[0])):
    
#     ax = fig.add_subplot(Rows, Cols, Position[k])
#     y[y.index.levels[0][k]].sort_values(ascending = False).head(5).plot(kind = "bar", edgecolor = "b", color = "gold")
#     plt.xlabel("\n" + 'Country', size = 45)
#     plt.ylabel('Percent', size = 45)
#     plt.ylim((0,105))
#     plt.title("\n" + str(y.index.levels[0][k]) + "\n", size = 60)
#     xlabels = [item.get_text() for item in ax.get_xticklabels()]
#     new = map(lambda x: x[x.find(",") + 2:-1], xlabels)
#     ax.tick_params(axis='y', which='major', labelsize=40)
#     ax.set_xticklabels(new, size = 30)
    
# plt.tight_layout()    
# plt.show()

# %%
# test = fiverr.groupby(["category","location"])["location"].size()
# test.groupby(level = [0]).transform(sum)
# x = test / test.groupby(level = [0]).transform(sum) * 100.00
# y = x.groupby(level = 0).nlargest(5)

# %%
# subcat_loc = fiverr.groupby(['category', 'subcategory'])
# y = subcat_loc.location.value_counts().groupby(level=[0,1]).nlargest(5)
# len(y.index.levels[1])

# %%
# Representation by Count of Top 5 Countries in each Subcategory

subcategory_df = fiverr.groupby(["subcategory", "location"]).location.agg("count")

Tot = len(subcategory_df.index.levels[0])
Cols = 4

# Compute Rows required

Rows = Tot // Cols 
Rows += Tot % Cols

# Create a Position index

Position = range(1,Tot + 1)

# # Create main figure

fig = plt.figure(figsize=(20,150))

cat_df = fiverr.groupby(["category"]).location.agg("count")

i = 0   

for cat in cat_df.index:
    subcat_df_full = fiverr.loc[fiverr.category == cat,]
    subcat_df = subcat_df_full.groupby(["subcategory", "location"]).location.agg("count")
    for k in range(len(subcat_df.index.levels[0])):
        ax = fig.add_subplot(Rows, Cols, Position[i])
        i += 1
        subcat_df[subcat_df.index.levels[0][k]].sort_values(ascending = False).head(5).plot(kind = "bar", edgecolor ="black", color = "teal")
        plt.xlabel('\n'+ 'Country', fontsize = 20)
        plt.ylabel('Count', fontsize = 20)
        plt.ylim((0,130))
        subcat = str(subcat_df.index.levels[0][k])
        cat = fiverr.loc[fiverr.subcategory == subcat, ].category.iloc[0,]
        title = "\n" + cat + ":" + "\n" + subcat
        plt.title(title, fontsize = 25)
        ax.set_xticklabels([item.get_text() for item in ax.get_xticklabels()], size = 15)
        ax.tick_params(axis='y', which='major', labelsize=15)
        

plt.tight_layout()    
plt.show()

# %%
# Response Time by Country for Subcategory in each Category

sns.reset_orig()
sns.set(font_scale=2)

for cat in set(fiverr.category):
    test = fiverr.loc[fiverr.category == cat, ]
    top5 = test.location.value_counts().head(5).index
    test2 = test.loc[test.location.isin(top5), ]
    sns.set_style("whitegrid")
    g = sns.factorplot(x = "ave_response_time_hrs", y="location", hue="subcategory",
               row="category", data=test2, kind="box", size=15, aspect=1);  
    g.set_xticklabels(size = 17)
    g.set_yticklabels(size = 17) 
    g.set(xlabel='Response Time (hours)', ylabel='Country')

# %%
# Star Rating by Country for Subcategory in each Category

sns.reset_orig()
sns.set(font_scale=2)

for cat in set(fiverr.category):
    test = fiverr.loc[fiverr.category == cat, ]
    top5 = test.location.value_counts().head(5).index
    test2 = test.loc[test.location.isin(top5), ]
    sns.set_style("whitegrid")
    g = sns.factorplot(y = "star_rating", x="location", hue="subcategory",
               row="category", data=test2, kind="box", size=15, aspect=1);  
    g.set_xticklabels(size = 20)
    g.set_yticklabels(size = 17) 
    g.set(xlabel='\n' + 'Star Rating', ylabel='Country' + '\n')

# %%
len(fiverr.ave_response_time_hrs)
# Out:
# 16312

# %%
len(fiverr.star_rating)
# Out:
# 16312

# %%
test = fiverr.dropna()

# %%
test.shape
# Out:
# (14802, 20)

# %%
fiverr.shape
# Out:
# (16312, 20)

# %%
sns.set(style="ticks")
g = sns.lmplot("norm_response_time", "star_rating", data = fiverr, size = 8, aspect = 1)
g.set_xticklabels(size = 10)
g.set_yticklabels(size = 10) 
g.set(xlabel='Response Time (normalized)', ylabel='Star Rating')
