# %%
import numpy as np
import pandas as pd
import sys
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
ls
# Out:
# Alldata.csv           Dataprocessing.ipynb  finalnfl.csv
# Alldata2.csv          Raggdata.csv          nflspider.py
# Alldata3.csv          Week4data.csv
# Alldata4.csv          __init__.py

# %%
# !cat finalnfl.csv
# Out:
# "","Date & Time","Favorite","Spread","Underdog","Total","Money Odds","Year","Week"
# "1","12/8 8:25 ET","At Kansas City","-3.5","Oakland",46,"-$195 +$170",2016,14
# "2","12/11 1:00 ET","At Tennessee","-2","Denver",44,"-$130 +$110",2016,14
# "3","12/11 1:00 ET","At Carolina","-1","San Diego",48.5,"-$120 +$100",2016,14
# "4","12/11 1:00 ET","At Indianapolis","-6.5","Houston",47.5,"-$290 +$240",2016,14
# "5","12/11 1:00 ET","Cincinnati","-5","At Cleveland",41.5,"-$220 +$180",2016,14
# "6","12/11 1:00 ET","Pittsburgh","-2","At Buffalo",45.5,"-$130 +$110",2016,14
# "7","12/11 1:00 ET","Arizona","-2","At Miami",44,"-$130 +$110",2016,14
# "8","12/11 1:00 ET","At Detroit","-7.5","Chicago",42,"-$360 +$300",2016,14
# "9","12/11 1:00 ET","Minnesota","-3.5","At Jacksonville",38,"-$180 +$160",2016,14
# "10","12/11 4:25 ET","At Tampa Bay","-2","New Orleans",52,"-$130 +$110",2016,14
# "11","12/11 1:00 ET","Washington","-2.5","At Philadelphia",48.5,"-$135 +$115",2016,14
# ...

# %%
#Load the data
nfl = pd.read_csv('finalnfl.csv')

# %%
#look at the data
nfl
# Out:
#       Unnamed: 0    Date & Time          Favorite Spread          Underdog  \
# 0              1   12/8 8:25 ET    At Kansas City   -3.5           Oakland
# 1              2  12/11 1:00 ET      At Tennessee     -2            Denver
# 2              3  12/11 1:00 ET       At Carolina     -1         San Diego
# 3              4  12/11 1:00 ET   At Indianapolis   -6.5           Houston
# 4              5  12/11 1:00 ET        Cincinnati     -5      At Cleveland
# 5              6  12/11 1:00 ET        Pittsburgh     -2        At Buffalo
# 6              7  12/11 1:00 ET           Arizona     -2          At Miami
# 7              8  12/11 1:00 ET        At Detroit   -7.5           Chicago
# 8              9  12/11 1:00 ET         Minnesota   -3.5   At Jacksonville
# 9             10  12/11 4:25 ET      At Tampa Bay     -2       New Orleans
# 10            11  12/11 1:00 ET        Washington   -2.5   At Philadelphia
# ...

# %%
completenfl = pd.read_csv('completenflAUS.csv')

# %%
completenfl.head()
# Out:
#          Date             Home Team             Away Team  Home Score  \
# 0  2017-02-05       Atlanta Falcons  New England Patriots          28
# 1  2017-01-22  New England Patriots   Pittsburgh Steelers          36
# 2  2017-01-22       Atlanta Falcons     Green Bay Packers          44
# 3  2017-01-15        Dallas Cowboys     Green Bay Packers          31
# 4  2017-01-15    Kansas City Chiefs   Pittsburgh Steelers          16
#
#    Away Score Overtime? Playoff Game? Neutral Venue?  Home Odds Open  \
# 0          34         Y             Y              Y            2.26
# 1          17       NaN             Y            NaN            1.43
# 2          21       NaN             Y            NaN            1.51
# 3          34       NaN             Y            NaN            1.50
# 4          18       NaN             Y            NaN            1.79
#
#    Home Odds Min  ...    Total Score Close  Total Score Over Open  \
# ...

# %%
#play around with slicing
print nfl.iloc[1:5,1:3]
# Out:
#      Date & Time         Favorite
# 1  12/11 1:00 ET     At Tennessee
# 2  12/11 1:00 ET      At Carolina
# 3  12/11 1:00 ET  At Indianapolis
# 4  12/11 1:00 ET       Cincinnati

# %%
#Return column names
list(nfl)
# Out:
# ['Unnamed: 0',
#  'Date & Time',
#  'Favorite',
#  'Spread',
#  'Underdog',
#  'Total',
#  'Money Odds',
#  'Year',
#  'Week']

# %%
#Renaming columns
# df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

# %%
nfl.columns
# Out:
# Index([u'Unnamed: 0', u'Date & Time', u'Favorite', u'Spread', u'Underdog',
#        u'Total', u'Money Odds', u'Year', u'Week'],
#       dtype='object')

# %%
type(nfl.columns)
# Out:
# pandas.indexes.base.Index

# %%
#Get rid of first column
nfl = nfl.drop(nfl.columns[0], axis=1)
nfl
# Out:
#         Date & Time          Favorite Spread          Underdog  Total  \
# 0      12/8 8:25 ET    At Kansas City   -3.5           Oakland   46.0
# 1     12/11 1:00 ET      At Tennessee     -2            Denver   44.0
# 2     12/11 1:00 ET       At Carolina     -1         San Diego   48.5
# 3     12/11 1:00 ET   At Indianapolis   -6.5           Houston   47.5
# 4     12/11 1:00 ET        Cincinnati     -5      At Cleveland   41.5
# 5     12/11 1:00 ET        Pittsburgh     -2        At Buffalo   45.5
# 6     12/11 1:00 ET           Arizona     -2          At Miami   44.0
# 7     12/11 1:00 ET        At Detroit   -7.5           Chicago   42.0
# 8     12/11 1:00 ET         Minnesota   -3.5   At Jacksonville   38.0
# 9     12/11 4:25 ET      At Tampa Bay     -2       New Orleans   52.0
# 10    12/11 1:00 ET        Washington   -2.5   At Philadelphia   48.5
# 11    12/11 4:05 ET  At San Francisco     -3           NY Jets   43.0
# ...

# %%
nfl.columns
# Out:
# Index([u'Date & Time', u'Favorite', u'Spread', u'Underdog', u'Total',
#        u'Money Odds', u'Year', u'Week'],
#       dtype='object')

# %%
nfl = nfl.rename(columns = {str(nfl.columns[0]):'Date'})

# %%
nfl.iloc[0,5]
# Out:
# '-$195 +$170'

# %%
nfl
# Out:
#                Date          Favorite Spread          Underdog  Total  \
# 0      12/8 8:25 ET    At Kansas City   -3.5           Oakland   46.0
# 1     12/11 1:00 ET      At Tennessee     -2            Denver   44.0
# 2     12/11 1:00 ET       At Carolina     -1         San Diego   48.5
# 3     12/11 1:00 ET   At Indianapolis   -6.5           Houston   47.5
# 4     12/11 1:00 ET        Cincinnati     -5      At Cleveland   41.5
# 5     12/11 1:00 ET        Pittsburgh     -2        At Buffalo   45.5
# 6     12/11 1:00 ET           Arizona     -2          At Miami   44.0
# 7     12/11 1:00 ET        At Detroit   -7.5           Chicago   42.0
# 8     12/11 1:00 ET         Minnesota   -3.5   At Jacksonville   38.0
# 9     12/11 4:25 ET      At Tampa Bay     -2       New Orleans   52.0
# 10    12/11 1:00 ET        Washington   -2.5   At Philadelphia   48.5
# 11    12/11 4:05 ET  At San Francisco     -3           NY Jets   43.0
# ...

# %%
#Change the date column to YYYY-MM-DD
#First kill everything after the first whitespace
nfl['Date'].replace(to_replace=r"^([^\s]*)\s.*", value=r"\1", regex=True)
# Out:
# 0        12/8
# 1       12/11
# 2       12/11
# 3       12/11
# 4       12/11
# 5       12/11
# 6       12/11
# 7       12/11
# 8       12/11
# 9       12/11
# 10      12/11
# 11      12/11
# 12      12/11
# 13      12/11
# 14      12/11
# 15      12/12
# 16      12/10
# 17      12/13
# 18      12/13
# 19      12/13
# 20      12/13
# 21      12/13
# 22      12/13
# 23      12/13
# 24      12/13
# 25      12/13
# 26      12/13
# 27      12/13
# 28      12/13
# 29      12/13
#         ...
# 2363     9/23
# 2364     9/23
# 2365     9/23
# 2366     9/23
# 2367     9/23
# 2368     9/23
# 2369     9/23
# 2370     9/23
# 2371     9/23
# 2372     9/23
# 2373     9/23
# 2374     9/23
# 2375     9/23
# 2376     9/23
# 2377     9/23
# 2378     9/24
# 2379     9/24
# 2380     9/24
# 2381     9/24
# 2382     9/24
# 2383     9/24
# 2384     9/24
# 2385     9/24
# 2386     9/24
# 2387     9/24
# 2388     9/24
# 2389     9/24
# 2390     9/24
# 2391     9/24
# 2392     9/25
# ...

# %%
#testing regex stuff and importing the required module
import re
re.search(r"^([^\s]*)\s.*", teststring).group(1)
# Out:
# 'At'

# %%
#before i do anything further, jusy copy the original data frame
nfloriginal = nfl.copy(deep=True)

# %%
#truncate nfl date to get rid of the time
nfl['Date'] = nfl['Date'].replace(to_replace=r"^([^\s]*)\s.*", value=r"\1", regex=True)

# %%
#change date to proper format
nfl['Date'] = nfl['Date'] + "/"+ nfl['Year'].astype(str)

# %%
nfl['Date']
nfl
# Out:
#             Date          Favorite Spread          Underdog  Total  \
# 0      12/8/2016    At Kansas City   -3.5           Oakland   46.0
# 1     12/11/2016      At Tennessee     -2            Denver   44.0
# 2     12/11/2016       At Carolina     -1         San Diego   48.5
# 3     12/11/2016   At Indianapolis   -6.5           Houston   47.5
# 4     12/11/2016        Cincinnati     -5      At Cleveland   41.5
# 5     12/11/2016        Pittsburgh     -2        At Buffalo   45.5
# 6     12/11/2016           Arizona     -2          At Miami   44.0
# 7     12/11/2016        At Detroit   -7.5           Chicago   42.0
# 8     12/11/2016         Minnesota   -3.5   At Jacksonville   38.0
# 9     12/11/2016      At Tampa Bay     -2       New Orleans   52.0
# 10    12/11/2016        Washington   -2.5   At Philadelphia   48.5
# 11    12/11/2016  At San Francisco     -3           NY Jets   43.0
# 12    12/11/2016           Seattle     -3      At Green Bay   47.0
# ...

# %%
#nfl['Date'].replace("/\//ig", value="-", regex=True)
nfl['Date'] = nfl['Date'].apply(lambda x: x.replace("/","-"))

# %%
nfl['Date'] = nfl['Date'].replace(to_replace=r"^(\d)(-\d*)(-\d*)", value=r"0\1\2\3", regex=True)
nfl
# Out:
#             Date          Favorite Spread          Underdog  Total  \
# 0      12-8-2016    At Kansas City   -3.5           Oakland   46.0
# 1     12-11-2016      At Tennessee     -2            Denver   44.0
# 2     12-11-2016       At Carolina     -1         San Diego   48.5
# 3     12-11-2016   At Indianapolis   -6.5           Houston   47.5
# 4     12-11-2016        Cincinnati     -5      At Cleveland   41.5
# 5     12-11-2016        Pittsburgh     -2        At Buffalo   45.5
# 6     12-11-2016           Arizona     -2          At Miami   44.0
# 7     12-11-2016        At Detroit   -7.5           Chicago   42.0
# 8     12-11-2016         Minnesota   -3.5   At Jacksonville   38.0
# 9     12-11-2016      At Tampa Bay     -2       New Orleans   52.0
# 10    12-11-2016        Washington   -2.5   At Philadelphia   48.5
# 11    12-11-2016  At San Francisco     -3           NY Jets   43.0
# 12    12-11-2016           Seattle     -3      At Green Bay   47.0
# ...

# %%
nfl['Date'] = nfl['Date'].replace(to_replace=r"^(\d*-)(\d)(-\d*)", value=r"\1 0\2\3", regex=True)
nfl
# Out:
#              Date          Favorite Spread          Underdog  Total  \
# 0     12- 08-2016    At Kansas City   -3.5           Oakland   46.0
# 1      12-11-2016      At Tennessee     -2            Denver   44.0
# 2      12-11-2016       At Carolina     -1         San Diego   48.5
# 3      12-11-2016   At Indianapolis   -6.5           Houston   47.5
# 4      12-11-2016        Cincinnati     -5      At Cleveland   41.5
# 5      12-11-2016        Pittsburgh     -2        At Buffalo   45.5
# 6      12-11-2016           Arizona     -2          At Miami   44.0
# 7      12-11-2016        At Detroit   -7.5           Chicago   42.0
# 8      12-11-2016         Minnesota   -3.5   At Jacksonville   38.0
# 9      12-11-2016      At Tampa Bay     -2       New Orleans   52.0
# 10     12-11-2016        Washington   -2.5   At Philadelphia   48.5
# 11     12-11-2016  At San Francisco     -3           NY Jets   43.0
# 12     12-11-2016           Seattle     -3      At Green Bay   47.0
# ...

# %%
#eliminate buffer whitespace
nfl['Date'] = nfl['Date'].apply(lambda x: x.replace(" ",""))

# %%
nfl
# Out:
#             Date          Favorite Spread          Underdog  Total  \
# 0     12-08-2016    At Kansas City   -3.5           Oakland   46.0
# 1     12-11-2016      At Tennessee     -2            Denver   44.0
# 2     12-11-2016       At Carolina     -1         San Diego   48.5
# 3     12-11-2016   At Indianapolis   -6.5           Houston   47.5
# 4     12-11-2016        Cincinnati     -5      At Cleveland   41.5
# 5     12-11-2016        Pittsburgh     -2        At Buffalo   45.5
# 6     12-11-2016           Arizona     -2          At Miami   44.0
# 7     12-11-2016        At Detroit   -7.5           Chicago   42.0
# 8     12-11-2016         Minnesota   -3.5   At Jacksonville   38.0
# 9     12-11-2016      At Tampa Bay     -2       New Orleans   52.0
# 10    12-11-2016        Washington   -2.5   At Philadelphia   48.5
# 11    12-11-2016  At San Francisco     -3           NY Jets   43.0
# 12    12-11-2016           Seattle     -3      At Green Bay   47.0
# ...

# %%
nfl['Date'] = nfl['Date'].replace(to_replace=r"^(\d*)-(\d*)-(\d*)", value=r"\3-\1-\2", regex=True)
nfl
# Out:
#             Date          Favorite Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City   -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee     -2            Denver   44.0
# 2     2016-12-11       At Carolina     -1         San Diego   48.5
# 3     2016-12-11   At Indianapolis   -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati     -5      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh     -2        At Buffalo   45.5
# 6     2016-12-11           Arizona     -2          At Miami   44.0
# 7     2016-12-11        At Detroit   -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota   -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay     -2       New Orleans   52.0
# 10    2016-12-11        Washington   -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco     -3           NY Jets   43.0
# 12    2016-12-11           Seattle     -3      At Green Bay   47.0
# ...

# %%
teststring  = nfl['Favorite'][0]
teststring2 = nfl['Favorite'][4]
bool(re.search(r'^(At )(.*)',teststring))
# Out:
# True

# %%
def isAway(x):
    matches = re.search(r'^(At )(.*)',x)
    if matches:
        return True
    else:
        return False

# %%
nfl['Home'] = ''
nfl['Away'] = ''
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
nfl.Spread.unique()
# Out:
# array(['-3.5', '-2', '-1', '-6.5', '-5', '-7.5', '-2.5', '-3', '-6', '-10',
#        '-8.5', '-4', '-12', '-8', '-10.5', '-9.5', '-9', '-1.5', '-13.5',
#        '-7', '-12.5', '-4.5', '-11', '-5.5', '-14', '-16', '-15', '-15.5',
#        '-14.5', '-11.5', '-17', '-13', '-20', 'PK', '-20.5', '-19',
#        '-16.5', '-24.5', '-27', '-17.5', '-19.5'], dtype=object)

# %%
#Getting rid of the PK's
nfl.Spread = nfl.Spread.astype(float)

# %%
nfl.Spread.unique()
# Out:
# array([ -3.5,  -2. ,  -1. ,  -6.5,  -5. ,  -7.5,  -2.5,  -3. ,  -6. ,
#        -10. ,  -8.5,  -4. , -12. ,  -8. , -10.5,  -9.5,  -9. ,  -1.5,
#        -13.5,  -7. , -12.5,  -4.5, -11. ,  -5.5, -14. , -16. , -15. ,
#        -15.5, -14.5, -11.5, -17. , -13. , -20. ,   0. , -20.5, -19. ,
#        -16.5, -24.5, -27. , -17.5, -19.5])

# %%
nfl['Money Odds'].map(str.replace(('$',''))
# Out:
#   File "<ipython-input-427-90449c3efcd4>", line 1
#     nfl['Money Odds'].map(str.replace(('$',''))
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
def isaway(x):
   if re.match(pattern='^At ', string=x['Favorite']) != None:
       return x['Favorite']
   else:
       return x['Underdog']

# %%
def ishome(x):
   if re.match(pattern='^At ', string=x['Favorite']) == None:
       return x['Favorite']
   else:
       return x['Underdog']

# %%
nfl['Away'] = nfl.apply(isaway, axis=1)

# %%
nfl['Home'] = nfl.apply(ishome, axis=1)

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
nfl['Money Odds'].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-441-f9feace3ad2d> in <module>()
# ----> 1 nfl['Money Odds'].unique().head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
nfl['Money Odds'] = nfl['Money Odds'].apply(lambda x: x.replace("$",""))

# %%
nfl['Favprob'] = ''

# %%
a = nfl['Money Odds'][0]
a
# Out:
# '-195 +170'

# %%
a.split(" ")
# Out:
# ['-195', '+170']

# %%
nfl['Money Odds'] = nfl['Money Odds'].map(lambda x: x.split(" "))

# %%
def makeprob(x):
    num1 = float(x['Money Odds'][0][1:])
    denom1 = float(num1 + 100)
    num2 = float(100)
    denom2 = float((num2 + float(x['Money Odds'][1][1:])))
    prob1 = num1/denom1
    prob2 = num2/denom2
    return (prob1/(prob1 + prob2))

# %%
nfl.loc[0,:]['Money Odds'][1][1:]
# Out:
# '170'

# %%
trial = nfl.loc[0,:]

# %%
makeprob(trial)
# Out:
# 0.6409007912355448

# %%
nfl['Favprob'] = nfl.apply(makeprob, axis = 1)

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
nfl['Dogprob'] = 1 - nfl['Favprob']

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
def homeprob(x):
    if x['Home'] == x['Favorite']:
        return x['Favprob']
    else:
        return x['Dogprob']
nfl['Homeprob'] = nfl.apply(homeprob,axis = 1)

# %%
nfl['Awayprob'] = 1 - nfl['Homeprob']

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
nfl.sort_values('Date', ascending = False)
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 183   2016-12-19     At Washington    -7.0          Carolina   51.0
# 170   2016-12-18         At Dallas    -7.0         Tampa Bay   47.5
# 171   2016-12-18      At NY Giants    -4.0           Detroit   42.0
# 172   2016-12-18      At Baltimore    -5.0      Philadelphia   41.0
# 173   2016-12-18         Green Bay    -4.5        At Chicago   40.5
# 174   2016-12-18      At Minnesota    -5.0      Indianapolis   45.0
# 175   2016-12-18        At Buffalo   -10.5         Cleveland   43.0
# 176   2016-12-18    At Kansas City    -6.0         Tennessee   43.0
# 177   2016-12-18        At Houston    -3.5      Jacksonville   39.5
# 178   2016-12-18        At Arizona    -3.0       New Orleans   48.0
# 179   2016-12-18        At Atlanta   -13.5     San Francisco   51.5
# 180   2016-12-18       New England    -3.0         At Denver   43.5
# 181   2016-12-18           Oakland    -2.5      At San Diego   50.0
# ...

# %%
#loaded completenfl data
completenfl.head()
# Out:
#          Date             Home Team             Away Team  Home Score  \
# 0  2017-02-05       Atlanta Falcons  New England Patriots          28
# 1  2017-01-22  New England Patriots   Pittsburgh Steelers          36
# 2  2017-01-22       Atlanta Falcons     Green Bay Packers          44
# 3  2017-01-15        Dallas Cowboys     Green Bay Packers          31
# 4  2017-01-15    Kansas City Chiefs   Pittsburgh Steelers          16
#
#    Away Score Overtime? Playoff Game? Neutral Venue?  Home Odds Open  \
# 0          34         Y             Y              Y            2.26
# 1          17       NaN             Y            NaN            1.43
# 2          21       NaN             Y            NaN            1.51
# 3          34       NaN             Y            NaN            1.50
# 4          18       NaN             Y            NaN            1.79
#
#    Home Odds Min  ...    Total Score Close  Total Score Over Open  \
# ...

# %%
len(completenfl['Home Team'].unique())
# Out:
# 33

# %%
len(nfl['Away'].unique())
# Out:
# 33

# %%
sorted(nfl['Home'].unique())
# Out:
# ['Arizona',
#  'Atlanta',
#  'Baltimore',
#  'Buffalo',
#  'Carolina',
#  'Chicago',
#  'Cincinnati',
#  'Cleveland',
#  'Dallas',
#  'Denver',
#  'Detroit',
#  'Green Bay',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'Kansas City',
#  'Los Angeles',
#  'Miami',
#  'Minnesota',
#  'NY Giants',
#  'NY Jets',
#  'New England',
#  'New Orleans',
#  'Oakland',
#  'Philadelphia',
#  'Pittsburgh',
#  'San Diego',
#  'San Francisco',
#  'Seattle',
#  'St. Louis',
#  'Tampa Bay',
#  'Tennessee',
#  'Washington']

# %%
sorted(completenfl['Home Team'].unique())
# Out:
# ['Arizona Cardinals',
#  'Atlanta Falcons',
#  'Baltimore Ravens',
#  'Buffalo Bills',
#  'Carolina Panthers',
#  'Chicago Bears',
#  'Cincinnati Bengals',
#  'Cleveland Browns',
#  'Dallas Cowboys',
#  'Denver Broncos',
#  'Detroit Lions',
#  'Green Bay Packers',
#  'Houston Texans',
#  'Indianapolis Colts',
#  'Jacksonville Jaguars',
#  'Kansas City Chiefs',
#  'Los Angeles Rams',
#  'Miami Dolphins',
#  'Minnesota Vikings',
#  'New England Patriots',
#  'New Orleans Saints',
#  'New York Giants',
#  'New York Jets',
#  'Oakland Raiders',
#  'Philadelphia Eagles',
#  'Pittsburgh Steelers',
#  'San Diego Chargers',
#  'San Francisco 49ers',
#  'Seattle Seahawks',
#  'St. Louis Rams',
#  'Tampa Bay Buccaneers',
#  'Tennessee Titans',
#  'Washington Redskins']

# %%
completenfl = completenfl.replace({'New York Giants':'NY Giants','New York Jets':'NY Jets'})

# %%
D = dict(zip(sorted(completenfl['Home Team'].unique()),sorted(nfl['Home'].unique())))

# %%
completenfl = completenfl.replace(D)

# %%
completenfl = completenfl.rename(columns={'Home Team': 'Home', 'Away Team': 'Away'})

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
#Get rid of the "At " in the away column
nfl['Away'] = nfl['Away'].apply(lambda x: x.replace("At ",""))

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
print len(completenfl)
print len(nfl)
# Out:
# 2937
# 2393

# %%
def homespread(x):
    if x['Favorite'] == x['Home']:
        return x['Spread']
    else:
        return (-1)*x['Spread']

# %%
#defining Homespread columns
nfl['Homespread'] = nfl.apply(homespread, axis =1)

# %%
#defining Awayspread columns
nfl['Awayspread'] = (-1)*nfl['Homespread']

# %%
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
trimmedcomplete = completenfl.iloc[:,0:6]

# %%
trimmedcomplete.head()
# Out:
#          Date         Home         Away  Home Score  Away Score Overtime?
# 0  2017-02-05      Atlanta  New England          28          34         Y
# 1  2017-01-22  New England   Pittsburgh          36          17       NaN
# 2  2017-01-22      Atlanta    Green Bay          44          21       NaN
# 3  2017-01-15       Dallas    Green Bay          31          34       NaN
# 4  2017-01-15  Kansas City   Pittsburgh          16          18       NaN

# %%
nfl.head()
# Out:
#          Date         Favorite  Spread      Underdog  Total    Money Odds  \
# 0  2016-12-08   At Kansas City    -3.5       Oakland   46.0  [-195, +170]
# 1  2016-12-11     At Tennessee    -2.0        Denver   44.0  [-130, +110]
# 2  2016-12-11      At Carolina    -1.0     San Diego   48.5  [-120, +100]
# 3  2016-12-11  At Indianapolis    -6.5       Houston   47.5  [-290, +240]
# 4  2016-12-11       Cincinnati    -5.0  At Cleveland   41.5  [-220, +180]
#
#    Year  Week        Home          Away   Favprob   Dogprob  Homeprob  \
# 0  2016    14     Oakland   Kansas City  0.640901  0.359099  0.359099
# 1  2016    14      Denver     Tennessee  0.542744  0.457256  0.457256
# 2  2016    14   San Diego      Carolina  0.521739  0.478261  0.478261
# 3  2016    14     Houston  Indianapolis  0.716570  0.283430  0.283430
# 4  2016    14  Cincinnati     Cleveland  0.658120  0.341880  0.658120
#
#    Awayprob  Homespread  Awayspread
# 0  0.640901         3.5        -3.5
# ...

# %%
nfl.sort_values('Date')
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 2205  2006-09-07     At Pittsburgh    -1.5             Miami   34.0
# 2217  2006-09-10        At Arizona    -9.5     San Francisco   43.5
# 2218  2006-09-10      Indianapolis    -3.0      At NY Giants   48.0
# 2216  2006-09-10           Chicago    -3.5      At Green Bay   34.5
# 2207  2006-09-10      At Tennessee    -3.0           NY Jets   35.5
# 2208  2006-09-10    At New England    -9.5           Buffalo   41.0
# 2209  2006-09-10      At Tampa Bay    -3.0         Baltimore   33.5
# 2210  2006-09-10    At Kansas City    -1.0        Cincinnati   48.5
# 2211  2006-09-10           Seattle    -6.0        At Detroit   44.0
# 2212  2006-09-10       At Carolina    -4.5           Atlanta   38.5
# 2213  2006-09-10      Philadelphia    -6.0        At Houston   38.0
# 2214  2006-09-10      At Cleveland    -3.0       New Orleans   36.5
# 2215  2006-09-10            Dallas    -2.0   At Jacksonville   36.5
# ...

# %%
trimmedcomplete.sort_values('Date')
# Out:
#             Date           Home           Away  Home Score  Away Score  \
# 2936  2006-09-07     Pittsburgh          Miami          28          17
# 2923  2006-09-10      Tennessee        NY Jets          16          23
# 2924  2006-09-10      Tampa Bay      Baltimore           0          27
# 2925  2006-09-10      St. Louis         Denver          18          10
# 2926  2006-09-10      NY Giants   Indianapolis          21          26
# 2927  2006-09-10    New England        Buffalo          19          17
# 2928  2006-09-10    Kansas City     Cincinnati          10          23
# 2935  2006-09-10        Arizona  San Francisco          34          27
# 2930  2006-09-10        Houston   Philadelphia          10          24
# 2934  2006-09-10       Carolina        Atlanta           6          20
# 2933  2006-09-10      Cleveland    New Orleans          14          19
# 2929  2006-09-10   Jacksonville         Dallas          24          17
# ...

# %%
#Dataset is ridiculous and backwards, need to flip flop:
nfl = nfl.rename(columns={'Home': 'Away', 'Away': 'Home'})

# %%
nfl = nfl.rename(columns={'Homeprob': 'Awayprob', 'Awayprob': 'Homeprob'})

# %%
nfl = nfl.rename(columns={'Homespread': 'Awayspread', 'Awayspread': 'Homespread'})

# %%
nfl.head()
# Out:
#          Date         Favorite  Spread      Underdog  Total    Money Odds  \
# 0  2016-12-08   At Kansas City    -3.5       Oakland   46.0  [-195, +170]
# 1  2016-12-11     At Tennessee    -2.0        Denver   44.0  [-130, +110]
# 2  2016-12-11      At Carolina    -1.0     San Diego   48.5  [-120, +100]
# 3  2016-12-11  At Indianapolis    -6.5       Houston   47.5  [-290, +240]
# 4  2016-12-11       Cincinnati    -5.0  At Cleveland   41.5  [-220, +180]
#
#    Year  Week        Away          Home   Favprob   Dogprob  Awayprob  \
# 0  2016    14     Oakland   Kansas City  0.640901  0.359099  0.359099
# 1  2016    14      Denver     Tennessee  0.542744  0.457256  0.457256
# 2  2016    14   San Diego      Carolina  0.521739  0.478261  0.478261
# 3  2016    14     Houston  Indianapolis  0.716570  0.283430  0.283430
# 4  2016    14  Cincinnati     Cleveland  0.658120  0.341880  0.658120
#
#    Homeprob  Awayspread  Homespread
# 0  0.640901         3.5        -3.5
# ...

# %%
trimmedcomplete.sort_values('Date').head()
# Out:
#             Date        Home          Away  Home Score  Away Score Overtime?
# 2936  2006-09-07  Pittsburgh         Miami          28          17       NaN
# 2923  2006-09-10   Tennessee       NY Jets          16          23       NaN
# 2924  2006-09-10   Tampa Bay     Baltimore           0          27       NaN
# 2925  2006-09-10   St. Louis        Denver          18          10       NaN
# 2926  2006-09-10   NY Giants  Indianapolis          21          26       NaN

# %%
nfl.sort_values('Date')
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 2205  2006-09-07     At Pittsburgh    -1.5             Miami   34.0
# 2217  2006-09-10        At Arizona    -9.5     San Francisco   43.5
# 2218  2006-09-10      Indianapolis    -3.0      At NY Giants   48.0
# 2216  2006-09-10           Chicago    -3.5      At Green Bay   34.5
# 2207  2006-09-10      At Tennessee    -3.0           NY Jets   35.5
# 2208  2006-09-10    At New England    -9.5           Buffalo   41.0
# 2209  2006-09-10      At Tampa Bay    -3.0         Baltimore   33.5
# 2210  2006-09-10    At Kansas City    -1.0        Cincinnati   48.5
# 2211  2006-09-10           Seattle    -6.0        At Detroit   44.0
# 2212  2006-09-10       At Carolina    -4.5           Atlanta   38.5
# 2213  2006-09-10      Philadelphia    -6.0        At Houston   38.0
# 2214  2006-09-10      At Cleveland    -3.0       New Orleans   36.5
# 2215  2006-09-10            Dallas    -2.0   At Jacksonville   36.5
# ...

# %%
nflmerged = pd.merge(nfl,trimmedcomplete,on = ['Date','Home','Away'])

# %%
len(nflmerged)
# Out:
# 2392

# %%
nflmerged.head()
# Out:
#          Date         Favorite  Spread      Underdog  Total    Money Odds  \
# 0  2016-12-08   At Kansas City    -3.5       Oakland   46.0  [-195, +170]
# 1  2016-12-11     At Tennessee    -2.0        Denver   44.0  [-130, +110]
# 2  2016-12-11      At Carolina    -1.0     San Diego   48.5  [-120, +100]
# 3  2016-12-11  At Indianapolis    -6.5       Houston   47.5  [-290, +240]
# 4  2016-12-11       Cincinnati    -5.0  At Cleveland   41.5  [-220, +180]
#
#    Year  Week        Away          Home   Favprob   Dogprob  Awayprob  \
# 0  2016    14     Oakland   Kansas City  0.640901  0.359099  0.359099
# 1  2016    14      Denver     Tennessee  0.542744  0.457256  0.457256
# 2  2016    14   San Diego      Carolina  0.521739  0.478261  0.478261
# 3  2016    14     Houston  Indianapolis  0.716570  0.283430  0.283430
# 4  2016    14  Cincinnati     Cleveland  0.658120  0.341880  0.658120
#
#    Homeprob  Awayspread  Homespread  Home Score  Away Score Overtime?
# ...

# %%
def homewins(x):
    if x['Home Score'] > x['Away Score']:
        return 1
    else:
        return 0

# %%
nfl['Homewins'] = nflmerged.apply(homewins,axis = 1)

# %%
nflmerged['Homewins'] = nflmerged.apply(homewins,axis = 1)

# %%
nfl.head()
# Out:
#          Date         Favorite  Spread      Underdog  Total    Money Odds  \
# 0  2016-12-08   At Kansas City    -3.5       Oakland   46.0  [-195, +170]
# 1  2016-12-11     At Tennessee    -2.0        Denver   44.0  [-130, +110]
# 2  2016-12-11      At Carolina    -1.0     San Diego   48.5  [-120, +100]
# 3  2016-12-11  At Indianapolis    -6.5       Houston   47.5  [-290, +240]
# 4  2016-12-11       Cincinnati    -5.0  At Cleveland   41.5  [-220, +180]
#
#    Year  Week        Away          Home   Favprob   Dogprob  Awayprob  \
# 0  2016    14     Oakland   Kansas City  0.640901  0.359099  0.359099
# 1  2016    14      Denver     Tennessee  0.542744  0.457256  0.457256
# 2  2016    14   San Diego      Carolina  0.521739  0.478261  0.478261
# 3  2016    14     Houston  Indianapolis  0.716570  0.283430  0.283430
# 4  2016    14  Cincinnati     Cleveland  0.658120  0.341880  0.658120
#
#    Homeprob  Awayspread  Homespread  Homewins
# 0  0.640901         3.5        -3.5       1.0
# ...

# %%
nfl = nfl.drop(nfl.columns[16], axis=1)
nfl
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
nflmerged
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
def overtotal(x):
    if (x['Home Score'] + x['Away Score']) > x['Total']:
        return 1
    elif (x['Home Score'] + x['Away Score']) == x['Total']:
        return 0.5
    else:
        return 0

# %%
nflmerged['Over'] = nflmerged.apply(overtotal,axis = 1)

# %%
nfl = nfl.drop(nfl.columns[16], axis=1)

# %%
sum(nflmerged.Over)/len(nflmerged)
# Out:
# 0.50668896321070234

# %%
def homecover(x):
    if x['Away Score'] - x['Home Score'] > x['Homespread']:
        return 0
    elif (x['Away Score'] - x['Home Score']) == x['Homespread']:
        return 0.5
    else:
        return 1

# %%
sum(nflmerged.apply(homecover,axis = 1))/len(nflmerged)
# Out:
# 0.48536789297658861

# %%
nflmerged['Homecover'] = nflmerged.apply(homecover,axis = 1)

# %%
nflmerged.head()
# Out:
#          Date         Favorite  Spread      Underdog  Total    Money Odds  \
# 0  2016-12-08   At Kansas City    -3.5       Oakland   46.0  [-195, +170]
# 1  2016-12-11     At Tennessee    -2.0        Denver   44.0  [-130, +110]
# 2  2016-12-11      At Carolina    -1.0     San Diego   48.5  [-120, +100]
# 3  2016-12-11  At Indianapolis    -6.5       Houston   47.5  [-290, +240]
# 4  2016-12-11       Cincinnati    -5.0  At Cleveland   41.5  [-220, +180]
#
#    Year  Week        Away          Home    ...      Awayprob  Homeprob  \
# 0  2016    14     Oakland   Kansas City    ...      0.359099  0.640901
# 1  2016    14      Denver     Tennessee    ...      0.457256  0.542744
# 2  2016    14   San Diego      Carolina    ...      0.478261  0.521739
# 3  2016    14     Houston  Indianapolis    ...      0.283430  0.716570
# 4  2016    14  Cincinnati     Cleveland    ...      0.658120  0.341880
#
#    Awayspread  Homespread  Home Score  Away Score  Overtime?  Homewins Over  \
# ...

# %%
sum(nflmerged['Overtime?'] == 'Y')
# Out:
# 141

# %%
a = sum(nflmerged['Homecover'] == 1)/float(len(nflmerged))

# %%
from math import *

# %%
sum(nflmerged['Homecover'] == 0.5)
# Out:
# 70

# %%
nonties = len(nflmerged)-70

# %%
a = sum(nflmerged['Homecover'] == 1)

# %%
(float(a)/nonties - .5)*sqrt(nonties)/(.25)
# Out:
# -2.905339763035221

# %%
b = sum(nflmerged['Homecover'] == 0)

# %%
(float(b)/nonties - .5)*sqrt(nonties)/(.5)
# Out:
# 1.4526698815176158

# %%
sum((nflmerged['Homespread']  0) & (nflmerged['Overtime?'] == 'Y'))
# Out:
# 49

# %%
a
# Out:
# 1126

# %%
nonties
# Out:
# 2322

# %%
2322/2
# Out:
# 1161

# %%
float(a)/nonties
# Out:
# 0.48492678725236865

# %%
from scipy import stats

# %%
stats.ttest_1samp(nflmerged['Homecover'][nflmerged['Homecover'] != 0.5],0.5)
# Out:
# Ttest_1sampResult(statistic=-1.4530174483584641, pvalue=0.1463540907640723)

# %%
stats.ttest_1samp(nflmerged['Homewins'][nflmerged['Homewins'] != 0.5],0.5)
# Out:
# Ttest_1sampResult(statistic=6.7269392141411126, pvalue=2.160639867324322e-11)

# %%
def totalscore(x):
    return (x['Home Score']+x['Away Score'])

# %%
nflmerged['Totalscore'] = nflmerged.apply(totalscore,axis =1)

# %%
nflmerged.groupby('Year')['Totalscore'].mean()
# Out:
# Year
# 2006    41.191964
# 2007    42.968610
# 2008    44.004505
# 2009    43.144796
# 2010    44.427885
# 2011    44.236364
# 2012    45.665158
# 2013    47.381818
# 2014    45.278846
# 2015    46.004673
# 2016    45.255924
# Name: Totalscore, dtype: float64

# %%
nflmerged.groupby('Home')['Homecover','Homeprob'].sum()
# Out:
#                Homewins   Homeprob
# Home
# Arizona              48  42.244085
# Atlanta              47  43.218460
# Baltimore            57  50.558417
# Buffalo              34  33.689294
# Carolina             44  44.922543
# Chicago              41  45.144530
# Cincinnati           40  41.594898
# Cleveland            28  33.158491
# Dallas               47  49.623283
# Denver               46  45.947633
# Detroit              37  38.960287
# Green Bay            54  51.282544
# Houston              42  42.933231
# Indianapolis         52  47.552190
# Jacksonville         32  35.843641
# Kansas City          36  38.582355
# Miami                37  38.267106
# Minnesota            46  40.845197
# NY Giants            44  48.363048
# NY Jets              38  39.960796
# New England          65  58.355110
# New Orleans          49  49.312445
# Oakland              29  33.045663
# Philadelphia         40  47.978379
# Pittsburgh           53  49.743856
# ...

# %%
# Replace LA with St. Louis
nflmerged = nflmerged.replace('Los Angeles','St. Louis')

# %%
nflmerged.head()
# Out:
#          Date         Favorite  Spread      Underdog  Total    Money Odds  \
# 0  2016-12-08   At Kansas City    -3.5       Oakland   46.0  [-195, +170]
# 1  2016-12-11     At Tennessee    -2.0        Denver   44.0  [-130, +110]
# 2  2016-12-11      At Carolina    -1.0     San Diego   48.5  [-120, +100]
# 3  2016-12-11  At Indianapolis    -6.5       Houston   47.5  [-290, +240]
# 4  2016-12-11       Cincinnati    -5.0  At Cleveland   41.5  [-220, +180]
#
#    Year  Week        Away          Home     ...      Homeprob  Awayspread  \
# 0  2016    14     Oakland   Kansas City     ...      0.640901         3.5
# 1  2016    14      Denver     Tennessee     ...      0.542744         2.0
# 2  2016    14   San Diego      Carolina     ...      0.521739         1.0
# 3  2016    14     Houston  Indianapolis     ...      0.716570         6.5
# 4  2016    14  Cincinnati     Cleveland     ...      0.341880        -5.0
#
# ...

# %%
nflmerged[nflmerged['Home'] == 'Cleveland'].sort_values('Date', ascending = True)
# Out:
#             Date      Favorite  Spread       Underdog  Total    Money Odds  \
# 2213  2006-09-10  At Cleveland    -3.0    New Orleans   36.5  [-200, +175]
# 2386  2006-09-24     Baltimore    -7.0   At Cleveland   33.0  [-360, +290]
# 1263  2006-10-22        Denver    -4.5   At Cleveland   31.5  [-230, +190]
# 787   2006-10-29  At Cleveland    -2.0        NY Jets   37.0  [-135, +115]
# 1106  2006-11-19    Pittsburgh    -4.5   At Cleveland   37.0  [-220, +180]
# 948   2006-11-26    Cincinnati    -3.5   At Cleveland   44.0  [-180, +160]
# 647   2006-12-03   Kansas City    -4.0   At Cleveland   35.5  [-210, +175]
# 2191  2007-09-09    Pittsburgh    -5.5   At Cleveland   36.0  [-260, +210]
# 1868  2007-09-16    Cincinnati    -7.5   At Cleveland   41.5  [-360, +290]
# 2025  2007-09-30     Baltimore    -4.0   At Cleveland   40.0  [-210, +175]
# 1552  2007-10-14  At Cleveland    -4.0          Miami   45.5  [-200, +175]
# ...

# %%
pd.set_option('display.max_columns', 50)

# %%
nflmerged.sort_values('Date', ascending = True).groupby(['Year','Week'])['Totalscore'].mean()
# Out:
# Year
# 2006    41.191964
# 2007    42.968610
# 2008    44.004505
# 2009    43.144796
# 2010    44.427885
# 2011    44.236364
# 2012    45.665158
# 2013    47.381818
# 2014    45.278846
# 2015    46.004673
# 2016    45.255924
# Name: Totalscore, dtype: float64

# %%
pwd
# Out:
# u'/Users/jackenyeart/Desktop/ScrapyProject/nfl/nfl/spiders'

# %%
# !cat NFLMERGEDFINAL.csv
# Out:
# ,Date,Favorite,Spread,Underdog,Total,Money Odds,Year,Week,Away,Home,Favprob,Dogprob,Awayprob,Homeprob,Awayspread,Homespread,Home Score,Away Score,Overtime?,Homewins,Over,Homecover,Totalscore
# 0,2016-12-08,At Kansas City,-3.5,Oakland,46.0,"['-195', '+170']",2016,14,Oakland,Kansas City,0.640900791236,0.359099208764,0.359099208764,0.640900791236,3.5,-3.5,21,13,,1,0.0,1.0,34
# 1,2016-12-11,At Tennessee,-2.0,Denver,44.0,"['-130', '+110']",2016,14,Denver,Tennessee,0.542743538767,0.457256461233,0.457256461233,0.542743538767,2.0,-2.0,13,10,,1,0.0,1.0,23
# 2,2016-12-11,At Carolina,-1.0,San Diego,48.5,"['-120', '+100']",2016,14,San Diego,Carolina,0.521739130435,0.478260869565,0.478260869565,0.521739130435,1.0,-1.0,28,16,,1,0.0,1.0,44
# 3,2016-12-11,At Indianapolis,-6.5,Houston,47.5,"['-290', '+240']",2016,14,Houston,Indianapolis,0.716569767442,0.283430232558,0.283430232558,0.716569767442,6.5,-6.5,17,22,,0,0.0,0.0,39
# ...

# %%
def awaywins(x):
    if x['Home Score'] < x['Away Score']:
        return 1
    else:
        return 0

# %%
nflmerged['Awaywins'] = nflmerged.apply(awaywins,axis = 1)

# %%
nflmerged['Awaycover'] = abs(nflmerged['Homecover']-1)

# %%
nflmerged
# Out:
#             Date          Favorite  Spread          Underdog  Total  \
# 0     2016-12-08    At Kansas City    -3.5           Oakland   46.0
# 1     2016-12-11      At Tennessee    -2.0            Denver   44.0
# 2     2016-12-11       At Carolina    -1.0         San Diego   48.5
# 3     2016-12-11   At Indianapolis    -6.5           Houston   47.5
# 4     2016-12-11        Cincinnati    -5.0      At Cleveland   41.5
# 5     2016-12-11        Pittsburgh    -2.0        At Buffalo   45.5
# 6     2016-12-11           Arizona    -2.0          At Miami   44.0
# 7     2016-12-11        At Detroit    -7.5           Chicago   42.0
# 8     2016-12-11         Minnesota    -3.5   At Jacksonville   38.0
# 9     2016-12-11      At Tampa Bay    -2.0       New Orleans   52.0
# 10    2016-12-11        Washington    -2.5   At Philadelphia   48.5
# 11    2016-12-11  At San Francisco    -3.0           NY Jets   43.0
# 12    2016-12-11           Seattle    -3.0      At Green Bay   47.0
# ...

# %%
nflmerged.to_csv("NFLMERGEDFINAL.csv")
